# %% [markdown]
# # Homework 2 - Considering Bias in Data
# The goal of this assignment is to explore the concept of bias in data using Wikipedia articles that are about political figures from different countries. We will combine a dataset of Wikipedia articles with a dataset of country populations, and use a machine learning service called ORES to estimate the quality of each article.
#
# ## License
# This code was developed by Sarah Nguyen for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [MIT License](https://chatgpt.com/c/67048ab0-3d24-8001-88ce-c354bb934b32#:~:text=under%20the%20MIT-,License,-.).

# %%
import pandas as pd
import json, time, urllib.parse
import requests

# %% [markdown]
# # Data Acquistion
# We need data that lists Wikipedia articles of politicians and data for country populations, which lives in different places.
#
# The `population_by_country_AUG.2024.csv` contains rows that provide cumulative regional population counts. These rows are distinguished by having ALL CAPS values in the 'geography' field (e.g. AFRICA, OCEANIA). These rows should not match the country values in `politicians_by_country.AUG.2024.csv`, but you will want to retain them so that you can report coverage and quality by region as specified in the analysis section below.

# %%
politicians_data = pd.read_csv('politicians_by_country_AUG.2024.csv')
population_data = pd.read_csv('population_by_country_AUG.2024.csv')

# %%
# Creates a list of diseases from the csv so we can loop through all diseases
if 'name' in politicians_data.columns:
    politician_list = politicians_data['name'].unique().tolist()

    print(politician_list)
# Out:
# ['Majah Ha Adrif', 'Haroon al-Afghani', 'Tayyab Agha', 'Khadija Zahra Ahmadi', 'Aziza Ahmadyar', 'Muqadasa Ahmadzai', 'Mohammad Sarwar Ahmedzai', 'Amir Muhammad Akhundzada', 'Nasrullah Baryalai Arsalai', 'Abdul Rahim Ayoubi', 'Ismael Balkhi', 'Abdul Baqi Turkistani', 'Mohammad Ghous Bashiri', 'Jan Baz', 'Bashir Ahmad Bezan', 'Rafiullah Bidar', 'Mohammad Siddiq Chakari', 'Cheragh Ali Cheragh', 'Nasir Ahmad Durrani', 'Muhammad Hashim Esmatullahi', 'Ezatullah (Nangarhar)', 'Aimal Faizi', 'Gajinder Singh Safri', 'Sharif Ghalib', 'Hashmat Ghani Ahmadzai', 'Abdul Ghani Ghani', 'Ghulam Ghaus', 'Ghulam Muhammad Ghobar', 'Mohammad Gul (Helmand Council)', 'Sayed Yousuf Halim', 'Rangina Hamidi', 'Sayed Zafar Hashemi', 'Qutbuddin Hilal', 'Mahboba Hoqomal', 'Musa Hotak', 'Mirza Muhammad Ismail', 'Sayed Jalal', 'Said Tayeb Jawad', 'Sayed Jalal Karim', 'Hafizullah Shabaz Khail', 'Masoud Khalili', 'Mohammad Khan (athlete)', 'Samoud Khan', 'Baran Khan Kudezai', 'Azizullah Lodin', 'Razaq Mamoon', 'Fazel Ahmed Manawi', 'Moeen Marastial', 'Ahmad Wali Massoud', 'Mohammad Daud Miraki', 'Abdul Sattar Mirzakwal', 'Abdul Karim Misaq', 'Ali Mohammad (politician)', 'Nasruddin Mohseni', 'Davood Moradian', 'Zalmai Mujadidi', 'Sardar Mohammad Nadir Naeem', 'Daoud Naji', 'Gholam Rabani Nasher', 'Ghulam Faroq Nijrabi', 'Zabih-U-llah Ghazi Noristani', 'Mohammed Tahir Omar', 'Mohammed Qalamuddin', 'Ghulam Mohammad Rigi', 'Ghulam Hassan Safi', 'Hanifa Safi', 'Mohammed Zia Salehi', 'Abdul Majid Samim', 'Saber Sangar', 'Sayed Nasim Mihanparast', 'Suhail Shaheen', 'Fazal Hadi Shinwari', 'Baktash Siawash', 'Hasan Ali Sultani', 'Mohammad Hashem Taufiqui', 'Pacha Gul Wafadar', 'Wahidullah Waissi', 'Ahmadullah Wasiq', 'Gul Ahmmad Yama', 'Abdul Salam Zaeef', 'Abdul Zahir (Konar Education Minister)', 'Mohammed Zaman', 'Ziauddin (Afghan militia leader)', 'Qari Ziauddin', 'Abdul Ghafor Zori', 'Ali Pasha of Gusinje', 'Ylli Asllani', 'Azis Tahir Ajdonati', 'Bislim Bajgora', 'Kastriot Berissa', 'Bardhok Biba', 'Kostandin Boshnjaku', 'Spartak Braho', 'Safet Butka', 'Uran Butka', 'Refo Çapari', 'Neritan Ceka', 'Hysni Curri', 'Ibrahim Dalliu', 'Niazi Demi', 'Abdurrahman Dibra', 'Bujar Dida', 'Ahmed Dino', 'Rasih Dino', 'Ferhat Bey Draga', 'Nexhip Draga', 'Aqif Pasha Elbasani', 'Abas Ermenji', 'Qamil Musa Haxhi Feza', 'Themistokli Gërmenji', 'Sabri Godo', 'Mihal Grameno', 'Aćif Hadžiahmetović', 'High Council of Regency', 'Kurt Agë Kadiu', 'Mehmed Kalakula', 'Alfred Karamuço', 'Ibrahim Karbunara', 'Ali Këlcyra', 'Bajram Kelmendi', 'Kristo Kirka', 'Elez Koçi', 'Xhelal Koprëncka', 'Kryeziu family', 'Artur Kuko', 'Xhavid Leskoviku', 'Sabit Lulo', 'Gjon Markagjoni', 'Tefik Mborja', 'Hysni Milloshi', 'Musa Qazimi', 'Mustafa Ndroqi', 'Behxhet Nepravishta', 'Adrian Neritani', 'Sali Nivica', 'Thoma Orologa', 'Bedri Pejani', 'Kadri Prishtina', 'Ymer Prizreni', 'Avni Rustemi', 'Chatin Sarachi', 'Nebi Sefa', 'Eduard Shalsi', 'Ylli Vesel Shehu', 'Athanas Shundi', 'Xhelal Sveçla', 'Mehmet Tahsini', 'Ibrahim Temo', 'Afrim Tole', 'Syreja Vlora', 'Visarion Xhuvani', 'Visar Ymeri', 'Abdyl Ypi', 'Xhezair Zaganjori', 'Menduh Zavalani', 'Abdelkader Zoukh', 'Chaâbane Aït Abderrahim', 'Ali Aoun', 'Basma Azouar', 'Mohamed Seghir Babes', 'Noureddine Bahbouh', 'Lamine Bechichi', 'Aïssa Bekkai', 'Abdelhakim Belabed', 'Mohamed Tarek Belaribi', 'Kamel Beldjoud', 'Aboubakr Belkaid', 'Youcef Belmehdi', 'Mohamed Cherif Belmihoub', 'Mohamed Belouizdad', 'Benaouda Hadj Hacène Bachterzi', 'Souad Bendjaballah', 'Abdelkrim Benmbarek', 'Mohamed Bensalam', 'Fayçal Bentaleb', 'Ahmed Bidani', 'Kamel Bidari', 'Rachid Bladehane', 'Saïd Boualam', 'Rabah Bouaziz', 'Abdeslam Bouchouareb', 'Ibrahim Boughali', 'Yahia Boukhari', 'Mohamed Bouslimani', 'Foued Chehat', 'Hamza Al Sid Cheikh', 'Hocine Cherhabil', 'Abderrahmane Meziane Chérif', 'Saïd Chibane', 'Brahim Chibout', 'Youcef Chorfa', 'Fazia Dahleb', 'Taha Derbal', 'Nassim Diafat', 'Mokhtar Didouche', 'Bouras Djamel', 'Fatiha Serour', 'Ahmed Hamiani', 'Nadir Kassab', 'Brah ...

# %% [markdown]
# ### Article Page Info MediaWiki API Example
#
# This example illustrates how to access page info data using the [MediaWiki REST API for the EN Wikipedia](https://www.mediawiki.org/wiki/API:Main_page). This example shows how to request summary 'page info' for a single article page. The API documentation, [API:Info](https://www.mediawiki.org/wiki/API:Info), covers additional details that may be helpful when trying to use or understand this example.
#
# ### License
# The next two code blocks are example code developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.2 - September 16, 2024

# %%
#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"
API_HEADER_AGENT = 'User-Agent'

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<uwnetid@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# # This is just a list of English Wikipedia article titles that we can use for example requests
# ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This is a modified version of his code
ARTICLE_TITLES = politician_list

# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    
    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['titles'] = article_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# put politician names into page info
# under api result, take revision ID and input rid into ORES API
# get output and take predicted quality score then you merge this info with 
# population dataset in csv file which he tell us column name
# do dataset and then do analysis

# %% [markdown]
# ## Step 2: Getting Article Quality Predictions
# In order to evaluate the predicted quality of each article in the Wikipedia dataset, we'll use a machine learning system called ORES. This was originally an acronym for "Objective Revision Evaluation Service" but was simply renamed “ORES”. ORES is a machine learning tool that can provide estimates of Wikipedia article quality.
#
# The article quality estimates are, from best to worst:
#
# FA - Featured article
#
# GA - Good article (also known as A-Class)
#
# B - B-Class article
#
# C - C-Class article
#
# Start - Start-class article
#
# Stub - Stub-class article
#
#
# In order use this tool, it requires a specific revision ID of an article to make a label prediction. Therefore, we need to get this information using the REST API. The steps to get an page quality prediction from ORES for each politician's article page are the following:
#
# a) read each line of `politicians_by_country.AUG.2024.csv`,
#
# b) make a page info request to get the current page revision, and
#
# c) make an ORES request using the page title and current revision id.

# %% [markdown]
# ### Part A & B: Make a page info request to get the current page revision for each line of `politicians_by_country.AUG.2024.csv`
#
# This is done by functions `batch_request_pageinfo` and `filter_pageinfo`.
# - `batch_request_pageinfo` calls the API to get the page information for multiple pages at the same time, by separating the page titles with the vertical bar "|" character. However, this approach has limits. You should probably check the API documentation if you want to do multiple pages in a single request - and limit the number of pages in one request reasonably. At the time of writing, the limit is 50 pages in a single request.
#
# - `filter_pageinfo` filters the page information we just got into `title:lastrevid`

# %%
def batch_request_pageinfo(ARTICLE_TITLES, batch_size=50):
    """
    Retrieve page information for a list of article titles in batches.

    This function processes a list of article titles by dividing them into batches of a specified size.
    For each batch, it sends a request to the page information API to fetch relevant data.
    The responses from all batches are aggregated and returned as a comprehensive collection of page data.

    Args:
        ARTICLE_TITLES (list of str):
            A list of article titles for which to retrieve page information.
        batch_size (int, optional):
            The number of titles to include in each API request batch.
            Defaults to 50 according to API documentation.

    Returns:
        list:
            A list containing the page information data retrieved from the API for all provided article titles.
            Each element in the list corresponds to the 'pages' data from an individual API response.
    """
    all_page_data = []  # To store all API responses

    # Doing this in batches/multipage resqest as this essentially means we are only doing one API call per batch - efficient time saver
    for i in range(0, len(ARTICLE_TITLES), batch_size):
        batch = ARTICLE_TITLES[i:i + batch_size]
        # Join the batch into a single string separated by '|', this creates a multipage request
        page_titles = '|'.join(batch)
        print(f"Getting page info data for: {page_titles}")

        request_info = PAGEINFO_PARAMS_TEMPLATE.copy()
        request_info['titles'] = page_titles
        info = request_pageinfo_per_article(request_template=request_info) # get API page info

        # Process the response
        if info and 'query' in info and 'pages' in info['query']:
            all_page_data.append(info['query']['pages'])  # Append the 'pages' part of the response
        else:
            print("No data returned for this batch.")

        # Put in an optional throttle the requests to avoid overloading the API
        time.sleep(API_THROTTLE_WAIT)

    return all_page_data

# %%
def filter_pageinfo(all_page_data):
    """
    Extract and filter relevant information from page data.

    This function processes a list of page data and extracts the 'title' and 'lastrevid' fields for each page.
    It returns a dictionary where the keys are the article titles and the values are the corresponding 'lastrevid' values.

    Args:
        all_page_data (list):
            A list of page data, where each element is a dictionary containing page information
            (typically the response from a page information API request).

    Returns:
        dict:
            A dictionary where keys are article titles and values are the corresponding 'lastrevid' values.

    Raises:
        ValueError:
            If any page data lacks the required 'title' or 'lastrevid' fields.
    """

    # Iterate through the full page data and extract title and lastrevid
    filtered_data = {}
    for pages in all_page_data:
        for page_id, page_data in pages.items():
            title = page_data.get('title')
            lastrevid = page_data.get('lastrevid')
            if title and lastrevid:
                filtered_data[title] = lastrevid  # Stores in a dictionary as 'title':lastrevid, which is desired input format for ORES
    return filtered_data

# %%
# Call the function to collect all the page data
all_page_data = batch_request_pageinfo(ARTICLE_TITLES)
# Out:
# Getting page info data for: Majah Ha Adrif|Haroon al-Afghani|Tayyab Agha|Khadija Zahra Ahmadi|Aziza Ahmadyar|Muqadasa Ahmadzai|Mohammad Sarwar Ahmedzai|Amir Muhammad Akhundzada|Nasrullah Baryalai Arsalai|Abdul Rahim Ayoubi|Ismael Balkhi|Abdul Baqi Turkistani|Mohammad Ghous Bashiri|Jan Baz|Bashir Ahmad Bezan|Rafiullah Bidar|Mohammad Siddiq Chakari|Cheragh Ali Cheragh|Nasir Ahmad Durrani|Muhammad Hashim Esmatullahi|Ezatullah (Nangarhar)|Aimal Faizi|Gajinder Singh Safri|Sharif Ghalib|Hashmat Ghani Ahmadzai|Abdul Ghani Ghani|Ghulam Ghaus|Ghulam Muhammad Ghobar|Mohammad Gul (Helmand Council)|Sayed Yousuf Halim|Rangina Hamidi|Sayed Zafar Hashemi|Qutbuddin Hilal|Mahboba Hoqomal|Musa Hotak|Mirza Muhammad Ismail|Sayed Jalal|Said Tayeb Jawad|Sayed Jalal Karim|Hafizullah Shabaz Khail|Masoud Khalili|Mohammad Khan (athlete)|Samoud Khan|Baran Khan Kudezai|Azizullah Lodin|Razaq Mamoon|Fazel Ahmed Manawi|Moeen Marastial|Ahmad Wali Massoud|Mohammad Daud Miraki
# Getting page info data for: Abdul Sattar Mirzakwal|Abdul Karim Misaq|Ali Mohammad (politician)|Nasruddin Mohseni|Davood Moradian|Zalmai Mujadidi|Sardar Mohammad Nadir Naeem|Daoud Naji|Gholam Rabani Nasher|Ghulam Faroq Nijrabi|Zabih-U-llah Ghazi Noristani|Mohammed Tahir Omar|Mohammed Qalamuddin|Ghulam Mohammad Rigi|Ghulam Hassan Safi|Hanifa Safi|Mohammed Zia Salehi|Abdul Majid Samim|Saber Sangar|Sayed Nasim Mihanparast|Suhail Shaheen|Fazal Hadi Shinwari|Baktash Siawash|Hasan Ali Sultani|Mohammad Hashem Taufiqui|Pacha Gul Wafadar|Wahidullah Waissi|Ahmadullah Wasiq|Gul Ahmmad Yama|Abdul Salam Zaeef|Abdul Zahir (Konar Education Minister)|Mohammed Zaman|Ziauddin (Afghan militia leader)|Qari Ziauddin|Abdul Ghafor Zori|Ali Pasha of Gusinje|Ylli Asllani|Azis Tahir Ajdonati|Bislim Bajgora|Kastriot Berissa|Bardhok Biba|Kostandin Boshnjaku|Spartak Braho|Safet Butka|Uran Butka|Refo Çapari|Neritan Ceka|Hysni Curri|Ibrahim Dalliu|Niazi Demi
# Getting page info data for: Abdurrahman Dibra|Bujar Dida|Ahmed Dino|Rasih Dino|Ferhat Bey Draga|Nexhip Draga|Aqif Pasha Elbasani|Abas Ermenji|Qamil Musa Haxhi Feza|Themistokli Gërmenji|Sabri Godo|Mihal Grameno|Aćif Hadžiahmetović|High Council of Regency|Kurt Agë Kadiu|Mehmed Kalakula|Alfred Karamuço|Ibrahim Karbunara|Ali Këlcyra|Bajram Kelmendi|Kristo Kirka|Elez Koçi|Xhelal Koprëncka|Kryeziu family|Artur Kuko|Xhavid Leskoviku|Sabit Lulo|Gjon Markagjoni|Tefik Mborja|Hysni Milloshi|Musa Qazimi|Mustafa Ndroqi|Behxhet Nepravishta|Adrian Neritani|Sali Nivica|Thoma Orologa|Bedri Pejani|Kadri Prishtina|Ymer Prizreni|Avni Rustemi|Chatin Sarachi|Nebi Sefa|Eduard Shalsi|Ylli Vesel Shehu|Athanas Shundi|Xhelal Sveçla|Mehmet Tahsini|Ibrahim Temo|Afrim Tole|Syreja Vlora
# Getting page info data for: Visarion Xhuvani|Visar Ymeri|Abdyl Ypi|Xhezair Zaganjori|Menduh Zavalani|Abdelkader Zoukh|Chaâbane Aït Abderrahim|Ali Aoun|Basma Azouar|Mohamed Seghir Babes|Noureddine Bahbouh|Lamine Bechichi|Aïssa Bekkai|Abdelhakim Belabed|Mohamed Tarek Belaribi|Kamel Beldjoud|Aboubakr Belkaid|Youcef Belmehdi|Mohamed Cherif Belmihoub|Mohamed Belouizdad|Benaouda Hadj Hacène Bachterzi|Souad Bendjaballah|Abdelkrim Benmbarek|Mohamed Bensalam|Fayçal Bentaleb|Ahmed Bidani|Kamel Bidari|Rachid Bladehane|Saïd Boualam|Rabah Bouaziz|Abdeslam Bouchouareb|Ibrahim Boughali|Yahia Boukhari|Mohamed Bouslimani|Foued Chehat|Hamza Al Sid Cheikh|Hocine Cherhabil|Abderrahmane Meziane Chérif|Saïd Chibane|Brahim Chibout|Youcef Chorfa|Fazia Dahleb|Taha Derbal|Nassim Diafat|Mokhtar Didouche|Bouras Djamel|Fatiha Serour|Ahmed Hamiani|Nadir Kassab|Brahim Djamel Kassali
# Getting page info data for: Kaoutar Krikou|Sassi Lamouri|Mohamed Maghlaoui|Amar Makhloufi|Yassine Merabi|Brahim Merad|Bachir Messaitfa|Azzedine Mihoubi|Mohamed Ali Boughazi|Amar Mohammedi|Samia Moualfi|Soraya Mouloudji|Yacine Oualid|Cherif Rahmani|Lakhdar Rakhroukh|Laid Rebiga|Kamel Rezig|Salim Saadi|Abdelhak Saihi|Hichem Sofiane Salaouatchi|Naima Salhi|Abderezak Sebgag|Abderrachid Tabbi|Karim Bibi Triki|Layachi Yaker|Ahmed Zeghdar|Adão Francisco Correia de Almeida|Ana Paula Chantre Luna de Carvalho|Alexandre Sebastião André|Paulino Baptista|Bernarda Gonçalves Martins|João Baptista Borges|Carolina Cerqueira|Arlete Chimbinda|Kafundanga Chingunji|Jeremias Chitunda|Abel Chivukuvuku|Fiel Domingos Constantino|Adalberto Costa Júnior|Adjany Costa|Álvaro Arnaldo Craveiro|Raul Danda|Diamantino Pedro Azevedo|Faustina Fernandes Inglês de Almeida Alves|Abraão Gourgel|Jofre Van-Dúnem Júnior|José Carvalho da Rocha|José Luis de Matos|Kambamba Kulaxingo|Jesus Faria Maiato
# Getting page info data for: Manuel Neto da Costa|Manuel Tavares de Almeida|Marcos Alexandre Nhunga|Maria Cândida Pereira Teixeira|Maria do Rosário Teixeira de Alva Sequeira Bragança Sambo|David Mendes|Saíde Mingas|Fernando Faustino Muteka|Pedro Mutinde|José Ndele|Ana Paula Sacramento Neto|Daniel Ntongi-Nzinga|Paula Cristina Francisco Coelho|Pedro Pedalé|Elias Salupeto Pena|Johnny Eduardo Pinnock|Santana André Pitra|Francisco Manuel Monteiro de Queiróz|José Aníbal Lopes Rocha|José da Rocha|Rosa Luís de Sousa Micolo|Luís Gomes Sambo|Branca Manuel Espirito Santo|João Ernesto dos Santos|José Filomeno dos Santos|Jonas Savimbi|Pinda Simão|Manuel Bernardo de Sousa|Augusto da Silva Tomás|José Jacinto Van-Dúnem|José Vieira Dias Van-Dúnem|Luzia Inglês Van-Dúnem|Manuel Vicente|Mfulupinga Nlando Victor|Clement Antonio|Randolph Beazer|Studiation Brown|Alex Browne (politician)|Colin O'Neil Browne|James Carlisle|Gail Christian|Mackenzie Frank|Osbert Richard Frederick|Caleb Gardiner|Shenella Mary Shadida Govia|William Haynes-Smith|Tim Hector|Cheryl Mary Clare Hurst|Wilfred Jacobs|Rick James (actor)
# Getting page info data for: Kiz Johnson|Fabian Jones|Johnathan Joseph (politician)|Kelvin Simon|Harold Lovell|Edmond Mansoor|David Massiah|Joanne Massiah|Dwayne George|Knacyntar Nedd|Melford Nicholas|Shawn Nicholas|Bernard Percival|Jamale Pringle|Philip Shoul|Rawdon Turner|Alincia Williams-Grant|Juan Alemann|Germán Alfaro|Joaquín Samuel de Anchorena|Juan Agustín Augier|Uladislao Augier|Marco Aurelio Avellaneda|Joaquín Belgrano|Antonio Bermejo|Antonio Beruti|Héctor Bidonde|Silvano Bores|Exequiel Bustillo|Mario Cafiero|Alberto Manuel Campos|Alejo Castex|Dámaso Centeno|Rossana Chahla|Lázaro Chiappe|Carlos Corach|Jorge Coscia|Carlos de la Rosa|Juan Carlos Del Bello|Luis L. Domínguez|Máximo Etchecopar|Héctor Toty Flores|Guillermo Francos|Juan Fugl|Santiago Gallo|Manuel José García|Juan José Gómez Centurión|Luis Carlos Gómez Centurión|Martín Guzmán|Federico Helguera
# Getting page info data for: Fernando Iglesias (Argentine politician)|Ricardo Kennedy|Carlos Kunkel|Norberto La Porta|Andrés Larroque|Julián de Leyva|Mónica López (politician)|Lucio Victorio Mansilla|Nicolás Massot|Martín Menem|Juan Mignaburu|Guillermo Montenegro|Mariano Moreno|Marcelo Muniagurria|Fernando Nadra|Rómulo Sebastián Naón|Santiago G. O'Farrell|Alfredo Olmedo|Miguel Ángel Pesce|Carlos Petroni|Alejo Peyret|Aldo Pignanelli|Abel Posse|Enrique S. Quintana|Amán Rawson|Martín Sabbatella|Juan Pablo Schiavi|Héctor Tizón|Claudio Uberti|Arístides Villanueva|Jorge Yoma|Ashot Arsenyan|Vigen Chitechyan|Hayk Chobanyan|Gurgen Egiazaryan|Parunak Ferukhan|Gevorg Ghazaryan (politician)|Andrias Ghukasyan|Aram Grigoryan (politician)|Vahagn Hovakimyan|Tigran Karapetyan|Tigran Khzmalyan|Mikayel Kotanyan|Hrant Maloyan|Khachatur Malumian|Aram Manukyan|Gevorg Melik-Karagyozyan|Vahan Minakhoryan|Ruben Miroyan|Ruben Mirzakhanyan
# Getting page info data for: Badal Muradyan|Narine Tukhikyan|Gabriel Noradoungian|Israel Ori|Paul Paul|Garo Paylan|Genrikh Poghosyan|Ishkhan Saghatelyan|Karen Sargsyan (sociologist)|Martiros Sarukhanyan|Vartkes Serengülian|Suren Shadunts|Ohannes Tchekidjian|Hrayr Tovmasyan|Usub Bek Temuryan|Kegham Vanigian|Serop Zakaryan|Alfons Adam|Ingo Appelt|Maximilian Anton Karl, Count Baillet de Latour|Heinrich Alfred Barb|Leopold Berchtold|Joseph Buttinger|Prince Carl of Solms-Braunfels|Count Václav Antonín Chotek of Chotkov and Vojnín|Citizens' Ministry|Richard von Coudenhove-Kalergi|Franz Dinghofer|George Abraham von Dyhrn|Eduard von Grebmer zu Wolfsthurn|Barbara Eibinger-Miedl|Hans Ferlitsch|Friedhelm Frischenschlager|Walter Guggenberger|Ulrich Habsburg-Lothringen|Ernst Hampel (politician)|Hans Peter Haselsteiner|Friedrich Wilhelm von Haugwitz|Eduard Hedvicek|Hermann Stern|Jürgen Himmelbauer|Anton Hofer|Andreas Hörtnagl|Franz Jetzinger|Konstantin Jireček|Hugo Jury|Joseph Kenner|Theodor Kery|Michael Killisch-Horn|Sophia Kircher
# Getting page info data for: Hubert Klausner|Martin Kocher|Józef Kożdoń|Gottfried von Kühnelt-Leddihn|Franz Leitner (politician)|Elmar Lichtenegger|Julius Lippert (historian)|Reinhold Lopatka|Karl Lütgendorf|Jürgen Mandl|Renate Mann|Ferdinand Mannlicher|Christoph Matznetter|Johann Gregor Memhardt|Franz Moroder|Heinz Nittel|Heidemaria Onodi|Brigitta Pallauf|Wladimir von Pawlowski|Johann Anton von Pergen|Gerhard Pfanzelter|Walter Pfrimer|Leopold Poetsch|Thomas Prinzhorn|Gregor Razumovsky (activist)|Horst Rosenkranz|Emil Sax|Peter Schieder|Karl Schmitzer|Sonja Zwazl|Georg Adam, Prince of Starhemberg|Gundaker Thomas Starhemberg|Josef Staribacher|Peter Strasser (politician)|Julius Tandler|Leopold, Count von Thun und Hohenstein|Karl Freiherr von Vogelsang|Anton von Winzor|Gisela Wurm|Alexander Zach|Curt Franz Wenzel Christoph Erdmann Graf Zedtwitz von Moraván und Duppau|Karl von Zinzendorf|Muzamil Abdullayev|Leyla Abdullayeva|Elchin Afandiyev|Fazail Agamali|Aliabbas Salahzade|Enver Alikhanov|Tarlan Aliyarbayov|Dilara Aliyeva
# Getting page info data for: Araz Alizadeh|Ali Asadov|Ashraf Bey Taghiyev|Chimnaz Aslanova|Akram Aylisli|Sahil Babayev|Huseyngulu Baghirov|Bakhish bey Rustambeyov|Alovsat Bakhshiyev|Mirgasim Cheshmazer|Vilayat Eyvazov|Abdurrahman Fatalibeyli|Fazail Ibrahimli|Afshan Gadimbeyova|Garib Karimoğlu|Gudrat Gasanguliev|Mehrali Gasimov|Solomon Grobshtein|Teymur Guliyev|Mammad Gurbanov|Musa Hacigasimov|Asaf Hajiyev|Haji Molla Ahmad Nuruzade|Farhad Hajiyev|Hasan Majidov|Hasan Hasanli|Jamil Hasanli|Ali M. Hasanov|Zakir Hasanov|Ali Huseynli|Alisahib Huseynov|Ali Ibrahimov|Irshad Aliyev|Mamed Iskenderov|Vidadi Isgandarov|Ajdar Ismailov|Saftar Jafarov|Jeyhun Jalilov|Arastun Javadov|Rovshan Javadov|Anar Karimov|Boris Kevorkov|Gurban Khalilov|Ahmad Kordary|Lutfali bey Behbudov|Ilham Madatov|Makhmud Mamed-Guliev|Majnun Mammadov|Musa Mammadov|Ramin Mammadov
# Getting page info data for: Elshad Mirbashir oghlu|Tahir Mirkishili|Movsum Samadov|Fuad Naghiyev|Eldar Namazov|Namig Nasrullayev|Siyavush Novruzov|Zahid Oruj|Sadig Rahimov|Suleyman Rahimov|Huseyn Rahmanov|Rovshen Rzayev|Hasan Seyidov|Hasan Seyidov (scientist)|Parviz Shahbazov|Mammad agha Shahtakhtinski|Abid Sharifov|Shirali Akhundov|Ikhtiyar Shirinov|Bakhtiyar Vahabzadeh|Vugar Mustafayev (minister)|Yusif Ziya Talibzadeh|Nurali Yusifbayli|Keith Bell (Bahamian politician)|Charles Carter (Bahamian journalist)|Harold Christie|Timothy Donaldson|Eugene Dupuch|Joseph Robert Love|McKell Bonaby|Pakesia Parker-Edgecombe|James Carmichael Smith (postmaster)|Mohammed Isa Al Abbasi|Abdulla Adel Fakhro|Abdullah bin Isa Al Khalifa|Ahmed Behzad (Bahrain)|Kamal Ahmed (politician)|Mohamed Ali Hasan Ali|Khalid Almoayed|Aymen Tawfeeq Almoayed|Nazar Al Baharna|Mahmood Al Bahrani|Ammar Al Bannai|Jawad Fairooz|Qasim Fakhro|Faisal al-Hamar|Nabeel bin Yaqub Al-Hamar|Isa bin Abdulrahman Al Hammadi|Jameel Humadan|Isa bin Ibrahim Al Khalifa
# Getting page info data for: Fahmi al-Jowder|Saud Kanoo|Essam Khalaf|Abdullah bin Hamad bin Isa Al Khalifa|Ahmed bin Mohamed Al Khalifa|Ali bin Khalifa Al Khalifa|Hala bint Mohammed Al Khalifa|Ibrahim ibn Khalifa Al Khalifa|Mai bint Mohammed Al Khalifa|Salman bin Khalifa Al Khalifa|Hamad Al Kooheji|Abdullatif Al-Mahmood|Rasheed Mohammed Al Maraj|Khalid Al Maskati|Abdulhussain bin Ali Mirza|Mohammed Al-Buainain|Mohammed bin Khalifa bin Ahmed|Mohammed bin Khalifa bin Ali Al Khalifa|Abdulrahman al-Nuaimi|Ammar Qambar|Isa Qassim|Abdulla Hassan Saif|Ali bin Saleh Al Saleh|Ahmed Al-Salloum|Salman bin Hamad Al Khalifa|Abdul Motaleb|Abdus Salam (Chattogram politician)|Abul Hashim|Oli Ahad|Chowdhury Shamsuddin Ahmed|Farid Ahmed|Muzaffar Ahmed (NAP politician)|AKM Hafizuddin|Mohammad Manjur Alam|M Hossain Ali|Aminul Islam Rabel|Mohammad A. Arafat|Ashab Uddin Ahmad|Shafiqur Rahman Badsha|Selina Banu|Nurul Huq Bhuiyan|Birendra Kishore Roaza|Bishnu Chattopadhyay|AKM Fazlul Kabir Chowdhury|Aminul Islam Chowdhury|Anwarul Karim Chowdhury|Moinuddin Ahmed Chowdhury|Sarwar Jan Chowdhury|Shahinur Pasha Chowdhury|Yusuf Ali Chowdhury
# Getting page info data for: Haji Mohammad Danesh|Pulin De|James Leo Ferguson|Abdul Halim Ghaznavi|Debendra Nath Ghosh|Ranesh Das Gupta|AKM Fazlul Haque (Jatiya Party politician)|Syed Najmuddin Hashim|M. Anwar Hossain|Nozir Hossain|Husam Uddin Chowdhury Fultali|Syed Muhammad Ibrahim|Abul Kashem|Abul Kashem Khan|Hatem Ali Khan|Muhammad Hamidullah Khan|Yar Mohammad Khan|Kazi Abdus Shahid Lal|Jyotirindra Bodhipriya Larma|Shamima Harun Lubna|Manik Lal Ray|Manjurul Imam|Mushrefa Mishu|Moin Uddin (politician)|Fazlul Haque Montu|Mujahidul Islam Selim|Mujibur Rahman (Chattogram politician)|Shafiul Alam Chowdhury Nadel|SM Nuruzzaman|Shamsul Huda Panchbagi|Muhammad Bayazeed Khan Panni|Ferdous Ahmed Qureshi|Asheq Ullah Rafiq|Abdur Rahim (scholar)|Habibar Rahman|M. M. Rahmatullah|Golam Maula Rony|Devasish Roy|Mahmudul Haque Sayem|Maulana Shakhawat|Abul Kalam Shamsuddin|Badruddoza Ahmed Shuja|Sourendra Nath Chakraborty|Mohammad Sultan|Syed Sayedul Haque Suman|Mohammad Toaha|Badruddin Umar|Zahidunnabi Dewan Shamim|Mohammad Zillur Rahman|Elliott Belgrave
# Getting page info data for: Chad Blackman|Santia Bradshaw|Sonia Browne|Michael A. Carrington|William Fondleroy Duguid|Reginald Farley|Adrian Forde|Cynthia Y. Forde|Ian Gooding-Edghill|Damien K. A. Griffith|Crystal Haynes|Philip St. Hill|Kirk Matthew Humphrey|Davidson Ishmael|Colin Everett Jordan|John Andrew King|Shantal Munro-Knight|Glyne Murray|Charles Duncan O'Neal|Samuel Jackman Prescod|Shanika Roberts-Odle|Ryan Straughn|Dwight Sutherland|Kerrie Symmonds|Yury Ambrazevich|Aliaksandr Azarau|Lyavon Barshchewski|Siarhei Cherachen|Zmitser Dashkevich|Siamion Domash|Tsimafei Dranchuk|Alaksandar Dubko|Gennady Grushevoy|Moshe Gutman|Uładzimir Hančaryk|Tamaš Hryb|Anatoĺ Kalinin|Voĺha Karač|Uładzisłau Kazłouski|Tadeusz Kościuszko|Ivan Kubrakov|Vladimir Kumets|Valery Levaneuski|Uladzimir Mackievič|V. L. Mukha|Jan Pazniak|Aleksandr Potupa|Pyotr Prakapovich|Alexander Radkov|Symon Rak-Michajłoŭski
# Getting page info data for: Vladimir Rusakevich|Ihar Rynkevich|Valery Sakhashchyk|Dominik Semashko|Aliaksandr Shakutsin|Nikolai Shelyagovich|Jan Stankievič|Mikola Statkevich|Sergei Tikhanovsky|Aleksandr Turchin|Yury Voskresensky|Edward Woyniłłowicz|Ivan Yermachenka|Manuel Abramowicz|Rudy Aernoudt|Herman Baltia|Jan Béghin|Frank Beke|Gustave Boël|Pol Clovis Boël|Antoine Brun|Fernand Cocq|Émile Coulonvaux|Auguste Couvreur|Nico Cué|Pierre David (mayor)|Marcel de Baer|August De Boodt|Norbert De Cuyper|Dirk De fauw|René De Feyter|François-Philippe de Haussy|Victor de Laveleye|Édouard Descamps|José Desmarets|Émile van Dievoet|Marc Drumaux|Jos Dupré|Françoise Dupuis|Veerle Geerinckx|Eugène Goblet d'Alviella|Julien Goekint|Jean-Pierre Grafé|Jacques Grippa|Guy Hance|Joris Helleputte|Lucienne Herman-Michielsens|Jules Hiernaux|Julius Hoste Jr.|Norbert Hougardy
# Getting page info data for: Joseph Houssa|Vincent Houssiau|Pierre Van Humbeeck|Dorah Ilunga|Pierre Imperiali|Jean-François Istasse|Milou Jeunehomme|Georges Kaeckenbeeck|André Kempinaire|Ahmet Koç (politician)|Willy Kuijpers|Rachid Madrane|Luc Michel|Fientje Moerman|André Molitor|Jean Pede|Pierre Emmanuel Félix Chazal|Jean-Marie Piret|André-Eugène Pirson|Marjet Van Puymbroeck|Jean Richardot the Younger|Gustave Rolin-Jaequemyns|Hippolyte Rolin|Father Samuel|Louis-Joseph Seutin|Alfons Siffer|Cyrille Tahay|Jacques Timmermans|Robert Urbain|Adolphe Van Glabbeke|Gaëtan Van Goidsenhoven|Jacques Van Gompel|Marcel Van Langenhove (referee)|Johan Verbeke|Yvan Verougstraete|Lodewijk Verreycken|Louis Waltniel|Yves de Wasseige|Roger Windels|Jacques van Ypersele de Strihou|Nemencio Acosta|Basilio Ah|Beverly Castillo|Charles Bartlett Hyde|Glenn Godfrey|Alexander Albert Hunter|Elfreda Reyes|Bert Tucker|Woldrich Harrison Courtenay|Arnauld Antoine Akodjènou
# Getting page info data for: Jules-Armand Aniambossou|Francis Covi|Sefou Fagbohoun|Louis Hunkanrin|Louis Ignacio-Pinto|Arouna Mama|D. N. Dhungyel|Dorjee Wangmo|Ugyen Dorji (DNT politician)|Zangley Dukpa|Dupthob|Choki Gyeltshen|Sherub Gyeltshen|Choida Jamtsho|Rinzin Jamtsho|Shingkhar Lam|Tshewang Lhamo|Kuenga Loday|Dorji Namgyal|Jigme Namgyal (Bhutan)|Kunzang C. Namgyel|Wangdi Norbu|Pema Chewang|Pema Gyamtsho|Kinga Penjor|Yeshey Penjor|Thakur S. Powdyel|Jai Bir Rai|Karma Rangdol|Chogyal Dago Rigdzin|Loknath Sharma|Tenzin (politician)|Sonam Tobgye|Dorji Tshering|Kinga Tshering|Namgay Tshering|Ugyen Tshering|Jigme Wangchuk|Lhatu Wangchuk|Khandu Wangchuk|Norbu Wangchuk|Tshering Wangchuk|Karma Donnen Wangdi|Tshencho Wangdi|Ugyen Wangdi|Dechen Wangmo (politician)|Dechen Zangmo|Neten Zangmo|Nidup Zangpo|Yeshey Zimba
# Getting page info data for: Botche Candé|Juliano Fernandes|Teodora Inácia Gomes|Desejado Lima da Costa|Aristide Menezes|Florentino Mendes Pereira|Carmelita Pires|Agnelo Regalla|Nataniel Aguirre|Francisco Argandoña|Atanasio de Urioste Velasco|Isaac Ávalos|Augusto Céspedes|Adolfo Chávez|Chi Hyun Chung|Pantaleón Dalence|Rafael Peña|Marcelo Elío|Marcial Fabricano|Fernando Eloy Guachalla|Toribia Lero Quispe|Antonio Machaca|Adolfo Mendoza|Manuel de Molina Zamudio|Pedro Domingo Murillo|Francisco Burdett O'Connor|Manuel Luis de Oliden|Simón Iturri Patiño|Bonifacio Pinedo|Julio Pinedo|Gary Prado Salmón|José Mariano Serrano|Moisés Torres (politician)|Fernando Vargas Mosua|Jaime de Zudáñez|Kemal Ademović|Mehmed Alajbegović|Boško Baškot|Salko Bukvarević|Sabina Ćudić|Dženan Đonlagić|Edin Forto|Dževad Galijašević|Josip Grubeša|Ankica Gudeljević|Hakija Hadžić|Mirsad Hadžikadić|Sanjin Halimović|Sevlid Hurtić|Husein Miljković
# Getting page info data for: Jasmin Imamović|Adamir Jerković|Esed Kadrić|Mehmed Kapetanović|Osman Karabegović|Rusmir Mahmutćehajić|Amor Mašović|Božidar Matić|Dragan Mektić|Ademaga Mešić|Jelka Miličević|Abdulah Mutapčić|Abdulah Nakaš|Damir Nikšić|Ismet Popovac|Hakija Pozderac|Hamdija Pozderac|Nurija Pozderac|Đuro Pucar|Svetozar Pudarić|Alen Šeranić|Uglješa Uzelac|Nezir Škaljić|Ibrahim Spahić|Jelena Trivić|Milan Uzelac|Dragan Vikić|Miloš Vukašinović|Philip Matante|Leetile Disang Raditladi|Patrick van Rensburg|Tobias de Aguiar|Medeiros e Albuquerque|Léo de Almeida Neves|Antônio Pinto Chichorro da Gama|Cipriano Barata|Jader Barbalho Filho|Irani Barbosa|Djalma Bastos de Morais|Henrique de Beaurepaire-Rohan, Viscount of Beaurepaire-Rohan|Natália Bastos Bonavides|Marcos Braz|Amador Bueno|Maurício Campos de Medeiros|Marcelo Cecé|Izolda Cela|Margarete Coelho|Paulo Corrêa|Miguel Couto|João Cunha (politician)
# Getting page info data for: Manuel Jacinto Nogueira da Gama, Marquis of Baependi|Aécio de Borba|José Abílio Silva de Santana|Alércio Dias|Délio dos Santos|Ademar Frederico Duwe|Paulo Cesar Farias|Emília Fernandes|José Carlos da Silva Mayrink Ferrão|Juscelino Filho|Pedro Paulino de Fonseca|Francisco Julião|Jofran Frejat|Almir Gabriel|Joaquim Gomes de Souza|Abdul Hamid Sebba|José Carlos Barbosa|José Eriberto Medeiros|Camila Jourdan|Jutahy Júnior|Joaquim Gonçalves Ledo|Antônio Leite Andrade|Ronaldo Lessa|Vinicius Lummertz|Londres Machado|Alceste Madeira|Beto Mansur|Pablo Marçal|Horácio de Matos|Sandra Meira Starling|Gerardo Melo Mourão|Murilo Melo Filho|Cândido Mendes de Almeida|Gilmar Mendes|Claudio Modesto|Carlos Eduardo Moreira Ferreira|José Múcio|Pedro Soares Muñoz|Paulo Nani|Dora Nascimento|Carlos Neder|Domingos Gomes de Aguiar Neto|Manuel Luís Osório, Marquis of Erval|Hildebrando Pascoal|Astrojildo Pereira|Joaquim Alvaro Pereira Leite|Francisco José Pinheiro|Mario Pinotti|Henrique Pizzolato|Plínio de Arruda Sampaio Jr.
# Getting page info data for: Marcio Pochmann|Presidency of Castelo Branco|Presidency of Eurico Gaspar Dutra|Presidency of Fernando Henrique Cardoso|Presidency of Itamar Franco|Presidency of Juscelino Kubitschek|Irondi Pugliesi|Eusébio de Queirós|Marco Antonio Raupp|Renan Contar|Robert Rey (plastic surgeon)|José Richa|Ary Rigo|Eduardo Rocha|Betinho Rosado|Rosana Martinelli|Antônio Ricardo dos Santos|Augusto Severo de Albuquerque Maranhão|José Manuel da Silva, Baron of Tietê|Fabiano Silveira|Vittorio Sorotiuk|Jose de Sousa Campos|Irineu Evangelista de Sousa, Viscount of Mauá|João Cardoso de Meneses e Sousa, Baron of Paranapiacaba|Aureliano Cândido Tavares Bastos|Juarez Távora (general)|Antônio de Queirós Teles, Baron of Jundiaí|Nelson Trad Filho|Evaristo da Veiga|Luís Viana Neto|Augusto Ximeno de Villeroy|André Zacharow|Murilo Zauith|Zeca do PT|Aleksandar Alekov|Anyu Angelov|Atanas Zapryanov|Atanas Atanasov (politician born 1990)|Atanas Atanasov (politician)|Hristo Atanassov|Jonas Basanavičius|Tsvetko Boboshevski|Alexander Bogoridi|Chairman (President) of Bulgaria|Dzhevdet Chakarov|Vasil Chichibaba|Lea Cohen|Vladimir Damgov|Stanislav Daskalov|Stefan Dimitrov (politician)
# Getting page info data for: Ivan Dimov (scientist)|Valentin Fortunov|Tsoncho Ganev|Georgi Gvozdeykov|Goritsa Grancharova|Ivancho Hadzhipenchovich|Ivan Demerdzhiev|Aleksi Ivanov|Grozdan Karadzhov|Vladimir Karolev|Georgi Kirkov|Spiro Kitinchev|Ivan Kondov|Kostadin Kostadinov (professor)|Gavril Krastevich|Petar Kulenski|Lazar Lazarov|Nikola Lazarov|Ivan Marazov|Venko Markovski|Yakov Matakiev|Ilian Mihov|Raya Nazaryan|Nikolay Milkov|Plamen Panayotov|Vladislav Panev|Asparuh Panov|Atanas Pekanov|Sasho Penov|Lyudmila Petkova|Hristo Petrov|Rosen Plevneliev|Aleksandur Pulev|Denitsa Simeonova|Ivan Stanchov|Kalin Stoyanov|Stanislav Stoyanov (politician)|Dragomir Stoynev|Teodora Genchovska|Daniel Valchev|Krasimir Valchev|Velko Valkanov|Ventsislav Varbanov|Damyan Velchev|Svetoslav Vitkov|Mincho Yovchev|Atanas Zafirov|Martin Zaimov|Dragomir Zakov|Nayden Zelenogorski
# Getting page info data for: Boureima Badini|Blaise Bassoleth|Nazi Boni|Eric Bougouma|François Compaoré|Daniel Ouezzin Coulibaly|Toubé Clément Dakio|Frédéric Guirma|Emile Ilboudo|Zinda Kaboré|Christophe Kalenzaga|Joséphine Drabo Kanyoulou|Joséphine Ki-Zerbo|Begnon-Damien Koné|Yabre Juliette Kongo|Kouamé Lougué|Jean-Baptiste Natama|Jean-Baptiste Ouédraogo|Mamadou Ouédraogo|Ousmane Bougouma|Pargui Emile Paré|Filippe Savadogo|Nouhoun Sigue|Diongolo Traore|Maurice Yaméogo|Saye Zerbo|Aung Than Oo|Aye Ko (artist)|Ba Shin|Bao Youxiang|Bawk Ja|Cheery Zahau|Oscar de Glanville|M. A. Gaffar|Han Tha Myint|Hla Maung Shwe|Hso Khan Pha|Nai Htaw Sorn|Htay Aung (businessman)|Htin Linn Aung|Ja Htoi Pan|Khin Kyaw Han|Khin Ma Ma Myo|Khin Maung Swe|Khun San Lwin|Ko Ni|Thakin Kodaw Hmaing|Kwe Te No|Sao Kya Seng|Kyaw Moe Tun
# Getting page info data for: Kyaw Myint|Kyaw Tun|Kyaw Zaw Oo|Duwa Lashi La|Lian Hmung Sakhong|Sultan Mahmud (minister)|Maran Brang Seng|Gani Markan|Maw Htun Aung|Myint Swe (politician, born 1965)|Myo Yan Naung Thein|Naw Ohn Hla|Nay Myo Wai|Nay Zin Lat|Kyaw Ni|Nyi Sein|Nyo Nyo Thin|Pu Pa Thang|San Tun|Sao Sanda|Sasa (politician)|Saw Sa|Saya Gyi U Nu|Sein Win (politician, born 1944)|Mya Lay Sein|Sao Seng Suk|Shwe Ohn|Soe Moe Hlaing|Sultan Ahmed (Burmese politician)|Naw Susanna Hla Hla Soe|Tan Yu Sai|Taw Phaya Galay|Tayzar San|Than Nyein|Than Sein|Than Win|Thaung Tun (politician)|Baganset U Thaw|Thein Maung|Thein Nyunt (politician)|Thet Win Aung|Thirty Comrades|Tin Aye|Tu Hkawng|Wai Moe Naing|Win Ko Ko Latt|Maung Wuntha|Yawd Serk|Za Hlei Thang|Zaw Htay
# Getting page info data for: Zura Begum|Pierre Baranyanka|Joseph Biroli|Evelyne Butoyi|Joseph Cimpaye|Edouard Nduwimana|Gervais Nyangoma|Gérard Mfuranzima|Cyrille Ndayirukiye|Révérien Ndikuriyo|Tharcisse Niyongabo|Gabriel Nizigama|Jean-Baptiste Ntidendereza|Ririkumutima|Agathon Rwasa|Imelde Sabushimike|Alexis Sinduhije|Ang Vong Vathana|Samheng Boros|Bun Chanmol|Chem Snguon|Chhan Sokhom|Chuon Saodi|Duong Sam Ol|Ieu Koeus|Ith Samheng|Khem Veasna|Kou Roun|Daran Kravanh|Lon Nil|Mao Ayuth|Neav Sithong|Ngoun Chhay Kry|Norodom Norindeth|Norodom Phurissara|Oung Ouen|Phlek Chhat|Ponn Vongs Vaddey|Samheng Bora|Say Phouthang|Sisowath Youtevong|So Nem|Tep Hun|Tep Phan|Tep Vattho|Thiounn|Touch Kim|Truong Cang|Tuot Saron|Uch Ven
# Getting page info data for: Uk Vithun|Ung Hong Sath|Veng Sakhon|Yat Hwaidi|Marie Catherine Abena|Haman Adama|Vincent de Paul Ahanda|Ahmadou Ahidjo|Joseph Beti Assomo|Charles Ateba Eyene|Olivier Bilé|Dsamou Micheline|Lawrence Fonka Shang|Victor Fotso|Séraphin Magloire Fouda|Lucy Gwanmesia|Njomgang Isaac|René Jam Afane|Augustine Ngom Jua|Paul Monyonge Kale|Enanga Kebbi|Pierre Kotouo|Laurentine Mbede|Albert Mbida|Ibrahim Mbombo Njoya|Clémentine Ananga Messina|Ousmane Mey|Victor Mukete|Bernard Muna|Jerôme Mvondo|Anne Marthe Mvoto|Hermine Patricia Tomaïno Ndam Njoya|Pierre Ngayewang|John Ebong Ngole|Xavier Ngoubeyou|Victor Anomah Ngu|Julienne Niat|Dorothy L. Njeuma|Bernard Njonga|Arouna N'Joya|Edouard Nomo-Ongolo|Antoine Ntsimi|André Ngongang Ouandji|Paul Pondi|Félix Sabal Lecco (politician)|François Sengat-Kuo|Madeleine Tchuente|Félix Tonye Mbog|Kah Walla|Zakiatou Djamo
# Getting page info data for: José Manuel Gomes Andrade|Honório Barreto|Pedro Fernandes Lopes|Januaria Moreira|Paulo Rocha (Cape Verde politician)|Gilberto Correia Carvalho Silva|Luís Filipe Tavares|Carlos de Vasconcelos|Abraão Vicente|Jean-Bédel Bokassa|Antoine Darlan|Georges Darlan|Catherine Denguiadé|Henri-Marie Dondra|Saif Durbar|Gaston N'Guérékata|Jean-Benoît Gonda|Hassan Al Habib|Rodolphe Iddi Lala|Désiré Kolingba|Tchakpa M'brede|Karim Meckassoua|Abakar Sabone|Levy Yakete|Achta Ahmat Bremé|Kamougue Assoum|Christian Georges Diguimbaye|Firmin Djidingar|Roger Djikisna|Issa Doubragne|Moussa Faki|Arabi El Goni|Isabelle Kassire|Oueddei Kichidemi|Alphonse Kotiga|Baba Laddé|Nadji Madou|Mahmoud Ali Seid|Mariam Mahamat Nour|Laoukein Kourayo Médard|Abbo Nassour|Tahir Hamid Nguilin|Quatre Sou Quatre|François Tombalbaye|Saadie Goukouni Weddeye|Alejandro Serani Burgos|Beltrán Mathieu|Alexandra Benado|Rolando Calderón|Eugenio Cantuarias
# Getting page info data for: Carlos Balmaceda Saavedra|Jorge Cauas|Alberto Cooper|Fernando Cordero Rusque|Juan de Dios Correa de Saa|María Silvia Correa Marín|Álvaro Covarrubias|Pedro Nolasco Cruz Vergara|Jose Fernandez Dubrock|Juan Egaña|Sergio Fernández Fernández|Ángel Flisfisch|Jaime Gazmuri|Carlos González Márquez|David Henríquez (footballer, born 1977)|Alejandra Bravo Hidalgo|Checho Hirane|Ricardo Hormazábal|Aucán Huilcamán|Liliana Jadue|Andrés Jouannet|Antonio Leal Labrín|Graciela Mandujano|Daniel Manouchehri|Rodrigo Mundaca|Sergio Ortega (composer)|Manuel Ossa Ruiz|Miguel Otero Lathrop|Sergio Páez Verdugo|Luis Palacios Rossini|Héctor Parra (footballer)|Ignacio Pérez Walker|Bernhard Eunom Philippi|Germán Picó Cañas|Tancredo Pinochet|Jaime Pizarro|Roberto Poblete|Francisco Prat Alemparte|Pablo Prieto|Valentina Quiroga|Patricio Rey Sommer|Claudio Reyes|Mario Ríos Santander|Jennifer Rojas|Miguel Schweitzer Walters|Loreto Silva|Roberto Thieme|Manuel Antonio Tocornal|Ramón Vega Hidalgo|Juan de Dios Vial del Río
# Getting page info data for: Claudio Vicuña Subercaseaux|Hernán Vodanovic|Chris Watson|Sergio Zarzar Andonie|Cao Lihuai|Fu Wenhua|Gu Shu|Hang Yihong|Hao Hongjun|Hoi Lai Fong|Hu Fuming|Jiao Xiaoping|Lin Shengzhong|Lu Feng (politician)|Shi Ping (politician)|Wang Liyan|Wang Yonghong|Wang Wei (politician, born 1974)|Wei Wenhui|Zhang Lin (general)|José Manuel Restrepo Abondano|Yahir Acuña|Iván Darío Agudelo|Carlos Mario Álvarez|Rafael Francisco Amador Campos|Julio Arboleda Pombo|Justo Arosemena Quesada|Germán Blanco Álvarez|Manuel José Bonnet|Wilson Borja|Gloria María Borrero|Carlos Fernando Galán|José Eusebio Caro|Ana María Castañeda|Iván Cepeda|Juan José Chaux Mosquera|Vicky Colbert|Alejandro Corrales Escobar|Alfredo Cuello Baute|Alfonso Dávila Ortiz|Luis Eduardo Díaz Granados|Olga Duque de Ospina|Eduardo Wiesner Durán|Eduardo Enríquez Maya|Miguel Amín Escaf|Juan Carlos Esguerra Portocarrero|Claudio Galán Pachón|Juan García del Río|Daniel García-Peña|Lucy Inés García
# Getting page info data for: Yaneth Giha Tovar|Enrique Gil Botero|Guillermo González (politician)|Bernardo Guerra Serna|Carlos Mauro Hoyos|Augusto Ibáñez Guzmán|Gilma Jiménez|Roberto Junguito|Maria Claudia Lacouture|Rodrigo Lara|Rodrigo Hernán Lloreda Caicedo|Francisco José Lloreda Mera|Fernando Londoño|Jorge Eduardo Londoño|Jorge Miguel Lozano, Marquis of San Jorge|David Luna Sánchez|Mariano Arosemena|Iván Marulanda|Carlos Eduardo Medellín Becerra|Germán Montoya Vélez|Lorenzo Muelas|Narciso Matus Torres|Elsa Noguera|Antonio Ordóñez Plaja|Fernando Ospina Hernández|Enrique Parejo González|Carlos Pizarro Leongómez|Daniel Quintero|Juan Camilo Quintero|Manuel María Ramírez Fortoul|Juan José Reyes-Patria Escobar|Ricardo Cobo|Jorge Enrique Robledo|Ángela Robledo|Antonio Roldán Betancur|Sixta Pontón de Santander|Juana de J. Sarmiento|Oscar Terán (lawyer)|Ernesto Macías Tovar|Ciro Luis Urriola|Ramón Maximiliano Valdés|Eduardo Valencia Ospina|Cristóbal de Vergara Azcárate|José María Vergara y Vergara|Estanislao Vergara y Sanz de Santamaría|Luis Villar Borda|Luis Carlos Villegas Echeverri|Roberto Camacho Weberberg|Mouzawar Abdallah|Moustadroine Abdou
# Getting page info data for: Ibrahim Aboubacar|Saïd Ibrahim Ben Ali|Mohamed Bacar|Chamina Ben Mohamed|Saïd Mohamed Cheikh|Mohamed Dahalani|Dhoihir Dhoulkamal|Ahmed Ben Said Djaffar|Abdou Soulé Elbak|Gaston Feuillard|Siti Kassim|Said Ali Kemal|Fouad Mohadji|Dawiat Mohamed|Sittou Raghadat Mohamed|Idi Nadhoim|Fahmi Said Ibrahim|Djaffar Ahmed Said|Abdallah Said Sarouma|Mohamed Ali Soilihi|Moussa Toybou|Léon Angor|Joseph Badiabio|Frédéric Bintsamou|Modeste Boukadia|Jean-Jacques Bouya|Fidèle Dimou|Gabriel Entcha-Ebia|Gabriel Valère Eteka Yemet|Albert Fourvelle|Pascal Gamassa|Pierre Goura|Gustave Aba-Gandzion|Joseph Hondjuila Miokono|Zely Pierre Inzoungou-Massanga|André Kerhervé|Pierre Mabiala|Paulin Makaya|Jean-Pierre Makouta-Mboukou|Jean Malonga|André Matsoua|Ferdinand Mbahou|Justin Mikolo-Kinzonzi|Bonaventure Mizidy|Émile Mokoko Wongolo|Jean-Marie Mokoko|René-Dambert Ndouane|Jean-Dominique Okemba|Denis-Christel Sassou Nguesso|Arlette Soudan-Nonault
# Getting page info data for: Jean Félix Demba Telo|Abel Thauley-Ganga|Daniel Aselo|Jean-Claude Baende|Bertrand Bisimwa|Célestin Cibalonza Byaterana|Martin Parfait Aimé Coussoud-Mavoungou|Emmanuel Dungia|Ferdinand Essandja|Floribert Anzuluni|Lugi Gizenga|Clovis Kabongo Malemba|Odilon Kafitwe wa pa Bowa|François Nicéphore Kakese|Kalenga Riziki Lwango II|Jean Collins Musonda Kalusambo|Norman Kamosi|Oscar Kashala|Banyingela Kasonga|Tharcisse Kasongo Mwema Yamba-Yamba|Albert-Joseph Kasongo Wa Kapinga|Pierre Honoré Kazadi Lukonda Ngube-Ngube|Jacques Kazadi|Léon Kengo wa Dondo|Robert Kidiaba|Seth Kikuni|Jean-Pierre Lola Kisanga|Delphin Kyubwa|Gabriel Kyungu|Eric Lenge|Faustin Luanga|Guy-Patrice Lumumba|Sultani Makenga|Angèle Makombo|Franck Mwe di Malila|Anne Mbusu|Munga Mibindo|Emile Mota|Josué Alex Mukendi|Daniel Mukoko Samba|Paul-Joseph Mukungubila|Medard Mulangala|Didier Mumengi|Kasongo Munganga|Jean-Claude Kazembe Musonda|Jules Mutebutsi|Laurent Nkunda|Muanda Nsemi|Victor Promontorio|Jean-Marie Runiga
# Getting page info data for: Alain Daniel Shekomba|Koloso Sumaili|Noël K. Tshiani Muadiamvita|Emery Wafwana|Yolande Ebongo Osongo|Florentino Alfaro Zamora|Alejandro Alvarado García|Antonio Saldaña|Armando Aráuz Aguilar|Birche|Tranquilino de Bonilla y Herdocia|Juan José de Bonilla y Herdocia|Miguel de Bonilla y Laya-Bolívar|Stephan Brunner|Marvin Calvo Montoya|Florencio del Castillo|Paola Vega Castillo|Ramón Castro y Ramírez|Ricardo Castro Beeche|Teodoro Willink Castro|José Joaquín Chaverri Sievert|José Miguel Corrales Bolaños|Correque|Aquileo J. Echeverría|El Guarco|Narciso Esquivel y Salazar|Alberto Fait Lizano|King Garabito|Gerardo Gómez Ramírez|Joaquín Gutiérrez|Fernando Guzmán Mata|Gerardo Guzmán Quirós|Joaquín de Iglesias Vidamartel|Bernal Jiménez Monge|Ramón Jiménez y Robredo|José Miguel Alfaro Rodríguez|Pedro María León-Páez y Brown|Óscar López (politician)|Juan de los Santos Madriz y Cervantes|Félix Arcadio Montero Monge|José Joaquín Mora Porras|Mary Munive|Rafael Moya Murillo|María Teresa Obregón Zamora|Rodrigo Oreamuno Blanco|Joaquín de Oreamuno|Rafael Francisco Osejo|Pablo Presbere|Manuel María de Peralta y Alfaro|José María de Peralta
# Getting page info data for: Manuel María de Peralta y López del Corral|Cipriano Pérez y Arias|Eusebio Prieto y Ruiz|Carmen Quesada Santamaría|José Pablo Quirós Quirós|Gregorio José Ramírez|Rafael Ramírez Hidalgo|Carlos Ricardo Benavides Jiménez|Rodrigo Altmann Ortiz|Santiago Mayas|Siarke|Tomás Enrique Soley Soler|José María Soto Alfaro|Nazario Toledo|Marco Vinicio Vargas Pereira|Santos Velázquez y Tinoco|William Forbes (Talamancan king)|Ivan Anušić|Mato Arlović|Branko Bačić|Fran Barac|Stephen Nikola Bartulica|Živko Bertić|Ante Biankini|Juraj Biankini|Antun Bonifačić|Andrija Torkvat Brlić|Josip Broz Tito|Gajo Bulat (politician, born 1867)|Nadežda Čačinovič|Gjuro Červar|Melko Čingrija|Pero Čingrija|Juraj Demetrović|Mate Drinković|Nikica Gabrić|Leon Geršković|Pavle Gregorić|Ernest Jelušić|Emerik Josipović|Gejza Josipović|Radovan Juričić|Luka Kirac|Stjepan Kovačević|Josip Kregar|Izidor Kršnjavi|Ivo Krstelj|Šime Kurelić|Ante Mandić|Gavro Manojlović
# Getting page info data for: Vladimir Mažuranić|Francesco Neffat|Fran Novljan|Adam Oster|Kata Pejnović|Ivo Pilar|Pero Pirker|Vladimir Prebeg|Svetozar Pribićević|Niko Pucić|Rafael Pucić|Ivica Puljak|Mario Radić (politician)|Svetozar Rittig|Juraj Rukavina Vidovgradski (politician)|Juraj Rukavina Vidovgradski (soldier)|Vjekoslav Servatzy|Ivan Vilibor Sinčić|Tadija Smičiklas|Predrag Štromar|Josip Juraj Strossmayer|Ante Šupuk|Đuro Šurmin|Petar Dragan Turković|Vjenceslav Turković|Ljudevit Vukotinović|Dragan Vulin|Većeslav Wilder|Lordan Zafranović|Ivana Živković|Savo Zlatić|Ante Županović|Prime Ministers of Cuba|President of Cuba|Eduardo Agramonte Piña|Ignacio Agramonte|Francisco Agüero Velasco|Alberto López Díaz|Sebastian Arcos Bergnes|Gustavo Arcos|Juan de Ayala y Escobar|Miguel Brugueras|Leopoldo Cancio|Demetrio Castillo Duany|Vicente Manuel de Céspedes|Manuel Cidre|Rosendo Collazo|Concepción Campa Huergo|José María Coppinger|Miguel Díaz-Canel
# Getting page info data for: Manuel Dorta-Duque|Carlos Fernández Gondín|Orestes Ferrara|Porfirio Franca|Francisco de Arango y Parreño|Edith García Buchaca|Eumelín González Sánchez|Aurelio Hevia|Fernando Heydrich|Alfredo Hornedo|José Irisarri|Perfecto Lacoste|José Francisco Lemus|Manuel Marrero Cruz|Rubén Martínez Puente|Augusto Martínez Sánchez|Bartolomé Masó|Ramón Meza y Suárez Inclán|Rafael Montoro|Bartolomé Morales|José Núñez de Cáceres|Juan Vitalio Acuña Núñez|Frank País|Pedro Esteban González-Larrinaga|Guillermo Portela|Juan Nepomuceno de Quesada|Luis Alberto Rodríguez López-Calleja|Francisco Sánchez Betancourt|Salvador José de Muro, 2nd Marquis of Someruelos|Laureano de Torres y Ayala|Salvador Valdés Mesa|Antonio Zambrana|Mine Atlı|Christos Christou (politician)|Ioannis Clerides|Katherine Clerides|Takis Evdokas|Oz Karahan|Stelios Koiliaris|Andreas Koukouma|Pantelis Kouros|Kyrillos III of Cyprus|Michalis Paraskevas|Christos Patsalides|Nicos A. Rolandis|Benon Sevan|Stefanos Stefanou|Michael Zampelas|Josef Barák|Dagmar Burešová
# Getting page info data for: František Ringo Čech|Jaroslav Chalupský|Petr Cibulka|Josef Šebestián Daubek|Karel Domin|Jaroslav Foldyna|Vladimír Franz|Josef Václav Frič|Radola Gajda|Julius Gregr|Tomáš Grulich|Karel Havlík|Vladimír Hučín|Stanislav Huml|Martin Jahn|Antonín Janoušek|Josef Ježek|Ladislav Jirků|Svatopluk Karásek|Wenzel Anton, Prince of Kaunitz-Rietberg|Philip Kinsky of Wchinitz and Tettau|Bohuslav Kokotek|Jiří Kopal|Jan Krejčí|Tomáš Kvapil|Jan Lacina|Lubomír Ledl|Miroslav Lidinský|Jiří Lobkowicz|Jiří Löw|Ivan Mašek|Mikuláš of Hus|Zdeněk Mraček|Jana Nečasová|Joseph Nekl|Jiří Oberfalzer|Roman Onderka|Vladimír Oplt|Mojmír Povolný|Vladimír Príkazský|Ondřej Přikryl|Jozef Regec|František Reichel|Bedřich Reicin|Richard Sacher|Tomáš Eduard Šilinger|Karel Sladkovský|Karel Štogl|Matěj Stropnický|Jiří Svoboda (director)
# Getting page info data for: Miroslav Tetter|Tomáš Vandas|Jiří Ventruba|Jan Vrba (politician)|Stanislav Žalud|Moussa Ali Abdoulkader|Djama Ali Moussa|Choukri Djibah|Omar Farah Iltireh|Daher Ahmed Farah|Ahmed Goumane-Roble|Halo Mohamed Ibrahim|Barkat Gourad Hamadou|Mahmoud Harbi|Abdallah Barkat Ibrahim|Mohamed Kamil|Mahamoud Moustapha Daher|Ahmed-Idriss Moussa|Omar Osman Rabe|Mohamed Warsama Ragueh|President of the Dominican Republic|Johnny Abbes|José Rafael Abinader|Yamil Abreu Navarro|Roberto Álvarez Gil|Casimiro Antonio Marte Familia|Ramón Marrero Aristy|José María Cabral y Báez|José María Caminero|Miguel Cocco|Ramón Tapia Espinal|Viriato Fiallo|Franklin Franco|José Gabriel García|Rosa Gómez de Mejía|Maximiliano Gómez|Juan Isidro Jimenes Grullón|Isabel Mayer|Valentin Medrano Pérez|Miguel Mejía (politician)|Matías Ramón Mella|Guillermo Moreno García|Juan Vicente Moscoso|José Ignacio Paliza|Porfirio Andrés Bautista García|Emilio Prud'Homme|Ramón Antonio Ramírez|Roberto Salcedo Sr.|Juan Sánchez Ramírez|Francisco del Rosario Sánchez
# Getting page info data for: Julián Serulle|Josefina Stubbs|Tomás Pimentel|Jack Veneno|Geovanny Vicente|Abelardo Vicioso|Elías Wessin y Wessin|Jorge Radhamés Zorrilla Ozuna|Aliança de Araújo|Manuel Carrascalão|Brigida Antónia Correia|Isabel da Costa Ferreira|Albina Marçal Freitas|Ángela Freitas|Justino Mota|Olinda Morais|Manuel Magalhaes de Oliveira|Alfredo Pires|Nino Konis Santana|José Abílio Osório Soares|João da Costa Tavares|Mário Viegas Carrascalão|Maria Terezinha Viegas|Luzmila Abad|Julio Martinez Acosta|Carlos Arizaga Toral|Aurora Estrada y Ayala|Fernando Balda|María Sol Corral|Jaime Durán Barba|Xavier Enderica|Isabel Enriquez|Ibeth Estupiñán|Guillermo Franco (Ecuadorian general)|Galo Lara|Andrea González Náder|Pablo Guerrero Martinez|Agustín Intriago|Jaminton Intriago|Roberto Izurieta|Marcel Jacobo Laniado de Wind|Luis A. Martínez|Pedro Moncayo|Mayra Montaño|Fabrizio Moreira|Diego Morejón|Catalina Ontaneda|Johanna Ortiz|Mónica Palencia|Ismael Pérez Pazmiño
# Getting page info data for: Filoteo Samaniego|Gabriela Sommerfeld|Arianna Tanca|Alfredo Vera Vera|Paola Vintimilla|Mariana Yumbay|Ahmad Pasha al-Munkali|Ahmed Issa (Egyptian politician)|Hamdi al-Sayyid|Mohsen Badawi|Abdelfattah al-Banna|Joseph Cattaui|Khaled Dawoud|Nabil Dibis|Ahmed Emad El-Din Radi|Sameh Seif El-Yazal|Ibrahim El-Gohary|Mamdouh Habib|Rafik Habib|Hisham Amna|Mohamed Ismail|Khaled Aly el-Bakly|Mostafa Madbouly|Mahmoud Ahmad Ibiary|Mahmoud Esmat|Mona Makram-Ebeid|Gawdat al-Malt|Ahmad Mazlum|George Messiha|Mohamed Maait|Mostafa Alnagar|Omar Marwan|Qatawi family|Diaa Rashwan|Talaat Sadat|Soares family|Soha Gendi|Youssef Zulficar Pasha|Abdullah Omran Taryam|Ahmed bin Mohammed Al Maktoum|Mohamed bin Hadi Al Hussaini|Hassan al Diqqi|Ahmed bin Rashid Al Maktoum|Ahmed bin Saeed Al Maktoum|Mohammed bin Khalifa Al Maktoum|Saeed bin Maktoum bin Hasher Al Maktoum|Hawaa Al Mansoori|Mohammed bin Saud Al Qasimi|Hamed bin Zayed Al Nahyan|Khaled bin Mohamed Al Nahyan
# Getting page info data for: Mohammed bin Khalifa bin Zayed Al Nahyan|Mohamed bin Zayed Al Nahyan|Saeed bin Zayed Al Nahyan|Saqr bin Zayed Al Nahyan|Shakhbut bin Sultan Al Nahyan|Mohammed Hussein Al Shaali|Abdulaziz Nasser Al Shamsi|Ahmad Al Tayer|Vice President of the United Arab Emirates|Felipe Hinestrosa Ikaka|Manuel Osa Nsue Nsua|Ahmed Mohammed Nasser|Ambaye Wolde Mariam|Girma Asmerom|Tedla Bairu|Hamid Ferej|Berhane Habtemariam|Habtezion Hadgu|Ibrahim Harun|Abraha Kassa|Abdulkadir Kebire|Abraham Kidane|Mohammed Saeed Nawed|Ibrahim Omer|Ali Radai|Romodan Mohammed Nur|Lehte Hainsalu|Carl Robert Jakobson|August Janson|Elmar Järvesoo|Harald Laksberg|Jüri Liim|Andi Meister|Friedrich Niggol|Andrei Prii|Theodor Rõuk|Toomas Sildmäe|Heino Sisask|Ants Tamme|Kirill Teiter|Georg Trašanov|Atnafu Abate|Abdirahman Eid Daahir|Mohamed Abdulghani|Abraham Tekeste|Agegnehu Teshager|Almayahu Haile|Getachew Assefa|Habtamu Ayalew Teshome|Lake Ayalew
# Getting page info data for: Saharla Abdulahi Bahdon|Juneidi Basha|Binalf Andualem|Mekdes Daba|Darge Sahle Selassie|Asrat Desta|Ergoge Tesfaye|Fitsum Assefa|Demelash Gebremichael|Alimirah Hanfare|Mawlid Hayir|Adem Ibrahim|Kemal Hashi Mohamoud|Kitaw Ejigu|Lencho Letta|Getahun Mekuria|Melatework Hailu|Mogus Wolde Mikael|Adem Mohammed|Jawar Mohammed|Belete Molla|Mulu Solomon|Su'ad Ahmed Farah|Tadesse Birru|Frehiwot Tamiru|Taye Atskeselassie|Habtamu Tegegne|Tekle Wolde Hawaryat|Teklewold Atnafu|Temesgen Tiruneh|Tsegaye Mamo|Andargachew Tsege|Yilkal Kefale|Sophia Yilma|Erik Berg (politician)|Arthur Brofeldt|Anders Chydenius|Selim Ekbom|Simon Ekpa|Erik Fleming (councilor)|Klaus Fleming|Timo Furuholm|Jakob Gadolin|Mikhail Fyodorovich Ganskau|Carl Axel Gottlund|Lars Gabriel von Haartman|Ilkka Hakalehto|Shawn Huff|Max Jakobson|Fritz Arthur Jusélius
# Getting page info data for: Aleksander von Kothen|Paul Kraatz|Antti Kuosmanen|Carl Fabian Langenskiöld|Reino Ragnar Lehto|Keijo Liinamaa|Olavi Mäenpää|Nils Mustelin|Johan Mauritz Nordenstam|Jaakko Numminen|Kirsi Piha|Toivo Topias Pohjala|Karl August Ramsay|Elisabeth Rehn|Matti Saarinen|Georg Magnus Sprengtporten|Jacob Magnus Sprengtporten|Aleksander Strandman|Christoffer Taxell|Heikki Heikinpoika Vaanila|Jaana Vasama|Miranda Vuolasranta|Nils Westermarck|Anders Wirenius|Konni Zilliacus (senior)|Pierre Baudis|Jean-François Bazin|Soheib Bencheikh|Georges Berthoin|Albert Bourderon|Bureau de La Rivière|Étienne-Laurent-Pierre Burnel|Jean Capelle (politician)|Ignace Caseneuve|Charles Cassal|Eddy Casterman|Jacques la Caze|Jean Charbonnel|Jean Auguste de Chastenet de Puységur|Pierre-Jean-Baptiste Chaussard|Henri Philippe de Chauvelin|Denis Clavel|Bruno Clavet|Maurice Colrat|Jean Cotereau|Paul Cotte|Michel Craplet|Jacques Antoine Creuzé-Latouche|Yves de Daruvar|Sandra Delannoy
# Getting page info data for: Victor Denain|Louis Grégoire Deschamps Destournelles|Martial Borye Desrenaudes|Nicolas du Bosc|Guillaume du Tillot|Théodore Ducos|Édouard Dunglas|Jules-François-Paul Fauris de Saint-Vincens|Jacques Fournier (government official)|Jean Frydman|Xavier de Fürst|Charles Ganilh|Agénor de Gasparin|Joseph Matthias Gérard de Rayneval|Charles Le Bègue de Germiny|Roland Giberti|Brigitte Girardin|Madeleine de Grandmaison|Jean-Henry-Louis Greffulhe|Alain Griset|Odette Grzegrzulka|Guillaume IV de Melun|Joseph-Ignace Guillotin|Joseph Guinard|Maurice d'Hartoy|Guy Hascoët|Paul Hay du Chastelet|Georges Humann|Philippe Hurault de Cheverny|Jean Louvet (politician)|Étienne de La Grange|Guillaume-Xavier Labbey de Pompières|Joachim Labrouche|Chrétien François de Lamoignon de Basville|Antoine-Adrien Lamourette|Hyacinthe Gaëtan de Lannion|Louis Lareng|Hippolyte Laroche|Jean Le Mercier|Julien Leonardelli|Charles Luca|Jacques-Antoine Manuel|Jacques Marquet de Montbreton de Norvins|Henri Martin (winemaker)|Philippe Massoni|Jean Mattéoli|Charlemagne de Maupas|Jeanne Mélin|Paul Mentré|Dominique Meyer
# Getting page info data for: Joseph François Augustin Monneron|Gérard Montassier|Guillaume-Isidore Baron de Montbel|Bernard Morel (economist)|Alex Moscovitch|Bernard Mourad|Ilham Moussaïd|Albert Ollivier|Érik Orsenna|Joseph Ostermann|Louis Pailhas|Philippe Paolantoni|Alexandre Parodi|Hélène Pelosse|Gilles Pennelle|François-Xavier de Peretti|Joseph Périer|Victor Perret|Marc Perrin de Brichambaut|Marcel Petiot|Henri Peyroux de la Coudrenière|Louis Phélypeaux, comte de Saint-Florentin|Louis Phélypeaux, Marquis of La Vrillière|Louis Phélypeaux, Seigneur of La Vrillière|Pierre Ferri-Pisani|Ernest Pinard|Antoine Portail|Michel Pouzol|Rodolphe Prager|Gabriel Puaux|Jean-Pierre Casimir de Marcassus, Baron de Puymaurin|Jean-Marie Rausch|Marie Roch Louis Reybaud|René Ribière|Antoine Richard du Cantal|Marthe Richard|Joseph Romain-Desfossés|Claude Taleb|François-Alexandre Tardiveau|Jean Tavernier|François Auguste de Thou|Charles de Varigny|Gaston Vidal|Jean-Paul-Alban Villeneuve-Barcement|Mathurin Anghiley|Anguilè Ré-Dowé|Jean-Hilaire Aubame|Ida Reteno Assonouet|Lee White (conservationist)|Amie Bojang-Sissoho
# Getting page info data for: Abdoulie Bojang|Buba Samura|Mai Fatty|Modou Bamba Gaye|Amadou Scattred Janneh|Fabakary Jatta|Dawda Jawara|Joseph Henry Joof|Ajaaratou Satang Jow|Kunda Kamara|Fatou Sanyang Kinteh|Muhammed Magassy|Alieu Badara Njie|Momodou Sabally|Lamin Saine|Pap Cheyassin Secka|Alieu Badara Saja Taal|Werner E. Ablaß|Shqiprim Arifi|Lena Arnoldt|Rudolf Bahro|Otto Ballerstedt|Bruno Baum|Karl Theodor Bayrhoffer|Otto Beck|Gerhard Besier|Georg von Blumenthal|Johann Christian von Boyneburg|Torben Braga|Ignatz Bubis|Wolf-Michael Catenhusen|John Ehret|Dieter Engels|Christian Wilhelm Karl Ewald|Christian August von Eyben|Georg Fein|Heinrich Fleißner|Winfried Fockenberg|Friedrich Johannes Frommann|Paul Fugger von Kirchberg und Weißenhorn|Günter Gaus|Friedrich von Gentz|Carl Heinrich Wilhelm Hagen|Gert Haller|Ludwig Hassenpflug|Hermann Heller (legal scholar)|Jakob Heller|Ernst Henrici|Rudolf Hilf|Joseph Hillebrand
# Getting page info data for: Franka Hitzing|Herwart von Hohenburg|Franz Christoph Anton, Count of Hohenzollern-Sigmaringen|Friedrich von Holstein|Martin Horn (politician)|Christoph Ernst von Houwald|Bernd Hüttemann|Emilie Kiep-Altenloh|Johann Ludwig Klüber|Werner Knieper|Caio Koch-Weser|Tobias Köck|Francis Kruse|Gottlob Johann Christian Kunth|Dieter Kunzelmann|Marianne Laqueur|Charles Lavy|Karl Ledderhose|Felix Lichnowsky|Moriz Lieber|Ludwig von Lützow (politician)|Carl Otto von Madai|Armin Mohler|Max Montgelas|Wolfgang Müller von Königswinter|Joseph Musiol|Theodor Olshausen|Dietrich Heinrich Ludwig von Ompteda|Max von Oppenheim|Christian Theodor Overbeck|Hans Paasche|Walter von Saint Paul-Illaire|Friedrich-Carl Peus|H. Busso Peus|Franz Seraph von Pfistermeister|Adolf Pilar von Pilchau|Gunter Pleuger|Johan Rantzau|Prince Richard of Hesse|Nela Riehl|Moritz Rittinghausen|Hermann Schäfer|Mike Schubert|Eduard von Schele zu Schelenburg|Paul Schiemann|Ernst Wilhelm von Schlabrendorf|Friedrich Gustav Carl Ulrich Franz von Schnehen|Joachim, Count of Schönburg-Glauchau|Peter Schott|Adam, Count of Schwarzenberg
# Getting page info data for: Veit Ludwig von Seckendorff|Paul Spiegel|Ashok-Alexander Sridharan|Gerhard Stahl|Karl von Starck|Henry Ernest of Stolberg-Wernigerode|Anna Strohsahl|Bertram von Sturm|Heinrich Sudermann|Wolfgang Templin|Stanislaw Trabalski|Adelheid Tröscher|Heinrich Voelter|Heinrich Alois von Reigersberg|Curt Wach|Ruth Weckenmann|Hellmuth Weiss|Hugo Wesendonck|Ludwig Georg Winter|Hermann Wittich|Agyen Kokobo|J. Nee Amahtey Hyde|Ofusu Kwabi|Richard Sumah|Sefis Anastasakos|Despina Chatzivassiliou-Tsovilis|Sofoklis Avraam Choudaverdoglou-Theodotos|Christos Daralexis|Alcibiades Diamandi|Ioannis Dimopoulos|Georgios Drys|Georgios Exintaris|Antonis Fosteridis|Asimakis Fotilas|Spyridon Galinos|Ioannis Gryparis (1848-1922)|Theophilos Kamberidis|Stavros Karampelas|Giorgos Katiforis|Matthaios Kofidis|Georgios Kourtoglou|Failos Kranidiotis|Eustathios Lagakos|Alexis Liatis|Nikolaos Makris|Ioannis Malachias|Ismail Molla|Yannis Moralis (politician)|Traianos Nallis|Theodoros Negris
# ...
# Getting page info data for: Eliaba James Surur|Al-Haj Adam Youssef|Yusuf al-Ajab|Thuli Dladla|Paul Dlamini|Russell Dlamini|Prince Sozisa Dlamini|Mduduzi Bacede Mabuza|Njabulo Mabuza|Themba Masuku|Mgwagwa Gamedze|Charles Myeza|Ben Nsibandze|Pholile Shakantu|Abraham Brodersson|Leila Ali Elmi|Bengt Snivil|Rudolf Fredrik Berg|Birger Jarl|Johan Ludvig Boye|Birger Brosa|Axel Brusewitz|Nils Claëson|Petrus Olai Dalekarlus|Christoffer Dulny|Klas Eklund|Martin Ekström|Nils Elowsson|Folke the Fat|Hans Reinhold von Fersen|Hemming Gadh|Gösta Hallberg-Cuula|Evelina Hahne|Greger Helin|Anders Henriksson (politician)|Carl P. Herslow|Holmger Knutsson|Albrecht Elof Ihre|Johan Gustaf Helin|Ida Karkiainen|Karl the Deaf|Gustav Kasselstrand|Mats Kettilmundsson|Per Klarberg|Sture Korpi|Henrik Landerholm|Yvonne Lindholm|Peeter Luksep|Vilhelm Lundström (philologist)|Eskil Magnusson
# Getting page info data for: Stig Malm|Ture Malmgren|Magnus Minniskiöld|Omar Mustafa|Reto Nause|Sven-Olle Olsson|Vera Oredsson|Gabriel Gustafsson Oxenstierna|Carl Fredrik Pechlin|Carl Piper|Filip Julius Bernhard von Platen|Tomas Polus|Nils Reuterholm|Qristina Ribohn|Oliver Rosengren|Karl Gustaf Scherman|Per Sefastsson|Erik Carlsson Sjöblad|Erik Sparre|Jimmy Ståhl|Adolf Ludvig Stierneld|Vávra Suk|Peter Sunde|August Tamm|Robert Macfie Thorburn|Jessica Thunander|Lars Törnman|Ulrika Björklund|Fredrik Vejdeland|Gustaf af Wetterstedt|Bertil Zachrisson|Arthur Bally|Gallus Jacob Baumgartner|Jacqueline Berenstein-Wavre|Toni Bortoluzzi|Franz Josef Bucher|Adolf Bühler Jr.|Thomas Burgherr|Achille Casanova|Conradin Cramer|Niklaus Dachselhofer|Denis de la Reussille|Josef Dittli|Ruggero Dollfus|Nina Fehr Düsel|Sigmund von Erlach|Johann Rudolf Faesch|Peter Falck|Annina von Falkenstein|Patricia von Falkenstein
# Getting page info data for: Laurence Fehlmann Rielle|Hans Fehr|Nils Fiechter|Ersilia Fossati|Samuel Frey|Benjamin Giezendanner|Urs Glutz von Blotzheim|Jean-Pierre Grin-Hofmann|Lars Guggisberg|Petermann von Gundoldingen|Martin Haab|Hans-Ulrich Bigler|André Hediger|Heidi Z'graggen|Georg Friedrich Heilmann|Thomas Helbling|David Hess (painter)|Karl Otto Hunziker|Jakob Stark|Jean-Pierre Hocké|Walter Kälin|Thomas Knutti|Kris Vietze|Frédéric-César de La Harpe|Georgie Lamon|Hubert Lauper|Paul Lüönd|Martin Hübscher|Ursula Mauch|Jakob Meyer zum Hasen|Kurt Meyer (Lucerne)|Simon Michel|Damian Müller|Peter Ochs|Giovanni Orelli|Ludwig Pfyffer|Paul Rechsteiner|Rudolf Rechsteiner|Ital Reding the Elder|Jules Repond|Estelle Revaz|Gebhard Rohner|Eduard August Rübel|Farah Rumy|Vinzenz Rüttimann|Gregor Rutz|Sergio Salvioni|Alfred Emanuel Sarasin|Nicolas Théodore de Saussure|Peter-Josef Schallberger
# Getting page info data for: Josef Scherrer|Jacob Schmidheiny|Nicola Siegrist|André Simonazzi|Vreni Spoerry|Niklaus Friedrich von Steiger|Silvia Steiner|Charles-Alexandre Steinhäuslin|Hansjörg Trachsel|Paul Usteri|Vroni Thalmann-Bieri|Eric Weber|Johann Rudolf Wettstein|Louis Wyrsch|Theodor Ab Yberg|Andrea Zryd|Sebastian Peregrin Zwyer|Ursula Zybach|Adil Arslan|Mohammed Akkad|Sultan al-Atrash|Ayyash Al-Haj|Ghias Barakat|Subhi Bey Barakat|Abdul Qader Barmada|Tawfiq Bay|Ibrahim Biro|Yusuf Franko Coussa|Amir al-Dandal|Abd al-Razzaq al-Dandashi|Ahmad Diyab|Hadad-yith'i|Hisham Marwah|Edmond Al-Homsi|Louay Hussein|Ihsan Al Jabri|Jihad Makdissi|Mohammad Jumah|Sami al-Jundi|Kamal al-Qassab|Kamil Pasha al-Qudsi|Abdul-Aziz al-Khair|Fayez al-Khoury|Mar'i Pasha al-Mallah|Antun Maqdisi|Mahmoud Ahmad Marei|Muhammad Talab Hilal|Mustafa al-Mousa|Mustafa al-Siba'i|Shukri al-Quwatli
# Getting page info data for: Nasim al-Safarjalani|Salem al-Meslet|Muhammad al-Sufi|Mohammad Farouk Tayfour|Huang Chaoqin|Li Huang|Lin Tze-luen|Liu Yongfu|Chiu Feng-chia|Jay N. Shih|Wu Fang-ming|Wu Heling|Xie Jieshi|Zheng Kezang|Olimzhon Boboyev|Mahmadali Hayit|Muhiddin Kabiri|Umarali Kuvvatov|Bobo Makhamov|Maksud Ibragimov|Nusratullo Maksum|Abduhalim Nazarzoda|Alim Sherzamonov|Shirinsho Shotemur|Bozor Sobir|Shukhrat Sultonov|Nur Tabar|Timothy Apiyo|Jumaa Aweso|Hussein Bashe|Maurice Henry Dorman|Fundikira III|Josephat Gwajima|Issa Kassim Issa|Bonnah Kaluwa|Michael Kamaliza|Jeremiah Kasambala|Hemed Khamis|Adam Kimbisa|Saed Kubenea|Elias John Kwandikwa|Theddy Ladislaus|Michael C. Latham|Paul Makonda|Julie Manning|Salome Joseph Mbatia|Ruth Hiyob Mollel|Ibrahim Saidi Rashidi Msabaha|Albert Msando|John Mwakangale
# Getting page info data for: Juma Mwapachu|Abdullah Mwinyi|Asanterabi Zephaniah Nsilo Swai|Mateo Qares|Augustino Ramadhani|Catherine Ruge|Festo Sanga|Abdallah Ulega|Mwita Waitara|Akanat Promphan|Borwornsak Uwanno|Bunsong Noisophon|Chada Thaiseth|Chaithawat Tulathon|Charoen Suepsaeng|Chatchawal Kong-udom|Chob Yodkaew|Cholnan Srikaew|Chonthicha Jaengraew|Chuwit Chitsakul|Hangthong Thammawattana|Kasidej Chutimant|Khrong Chandawong|Kriangkrai Srirak|Maris Sangiampongsa|Mongkol Surasajja|Natthaphong Ruengpanyawut|Nukun Prachuapmo|Padipat Suntiphada|Pallop Pinmanee|Phayom Chulanont|Pichit Chuenban|Pita Limjaroenrat|Rangsiman Rome|Rukchanok Srinork|Samak Jalikula|Sang Phathanothai|Sereepisuth Temeeyaves|Singsuk Singpai|So Sethaputra|Sodsai Rungphothong|Sophon Suphapong|Suchatvee Suwansawat|Surangkana Wayuparb|Suriya Chindawongse|Sutin Klungsang|Teerakiat Jaroensettasin|Thamanat Prompow|Tiang Sirikhanth|Vichien Khaokham
# Getting page info data for: Luang Wichitwathakan|Jacques Amouzou|Myriam Dossou D'Almeida|Issifou Tabiou Taffa|Kodjo Amegnisso Tossou|Clément Nyaletsossi Voule|Sani Yaya|Solomone Ula Ata|Shirley Waldemar Baker|Enele Maʻafu|Siaosi Tukuʻaho|Semisi Sika|Sione Tupou Mateialona|Siosateki Tonga|Tevita Tuʻivakano|Viliami Tupoulahi Mailefihi Tuku'aho|ʻUluvalu|Henry Alcazar|James Biggart|Cyrus Prudhomme David|William Demas|Gypsy (calypsonian)|Isaac Hope|Rudranath Indarsingh|Martin Joseph|Kenneth Lalla|Emmanuel Mzumbo Lazare|Randall Mitchell|Arnold Piggott|David Pitt, Baron Pitt of Hampstead|Kevin Ramnarine|Richie Sookhai|Sarran Teelucksingh|Ronald Jay Williams|Hugh Wooding|Habib Achour|Mekki Aloui|Ferjani Bel Haj Ammar|Chedly Ayari|Mahmoud Ben Ayed|Mounir Baatour|Selma Baccar|Yadh Ben Achour|Nizar Ben Néji|Ahmed Ben Salah|Leila Ben-Gacem|Mohamed Nejib Berriche|Khemais Chammari|Ghazi Chaouachi|Ali Chaouch
# Getting page info data for: Mohamed Charfi|Mohamed Messaoud Chebbi|Ahmad ibn Abi Diyaf|Mahmoud Djellouli|Kamel Feki|Mohamed Salah Fliss|Mohamed Ghannouchi|Rached Ghannouchi|Sadok Ghileb|Nebiha Gueddana|Mezri Haddad|Radhia Haddad|Ali Bach Hamba|Olfa Hamdi|Mohamed Hechmi Hamdi|Kamel Idir|Chaima Issa|Kamel Jendoubi|Faten Kallel|Ibrahim Kassas|Othman Kechrid|Omezzine Khelifa|Khemaïs Ksila|Slaheddine Maaoui|Selma Hédia Mabrouk|Zouhair Maghzaoui|Seifeddine Makhlouf|Mohamed Masmoudi|Mustapha Masmoudi|Tarak Mekki|Ahmed Mestiri|Naceur Ben Jaâfar|Mahmud Qabadu|Giuseppe Raffo|Mustapha Saheb Ettabaa|Salah Farhat|Saïda Sassi|Béchir Sfar|Tahar Sfar|Ahmed Tlili|Imed Trabelsi|Mohamed Larbi Zarrouk|Ali Zouaoui|Avni Akyol|Ali Cenani|Cihan Alptekin|Kadri Altay|Fahrettin Altun|Oğuzhan Asiltürk|Can Atalay
# Getting page info data for: Aziz Feyzi Pirinççizâde|Abdurrahman Başkan|Hasan Basri Güzeloğlu|Fahri Batıca|Tuna Bekleviç|Cemil Bilsel|Ahmet Çakır|Remzi Çayır|Davut Gül|Tuncay Dinç|Edip Rüştü Akyürek|Eyüp Sabri Hayırlıoğlu|Ali Fidan|Taha Genç|Hasan Reşit Tankut|Hayati Vasfi Taşyürek|Atıf Kamçıl|İmran Kılıç|Ertuğrul Mat|Mehmet Fatih Kacır|Mehmet Kamaç|Hafız Mehmet|Abdurrahman Melek|Kemal Memişoğlu|Mustafa Arif Deymer|Memduh Oğuz|Yaşar Okuyan|Saruhan Oluç|Fuat Necati Öncel|Cahit Ortaç|Osman Nuri Önügören|Faik Ali Ozansoy|Vahdettin Özkan|Osman Pamukoğlu|Musa Piroğlu|Reşit Ronabar|Kader Sevinc|Hüseyin Sungur|Kemal Tekden|Mustafa Timisi|Turgut Okyay|Ziya Uğur|Suut Kemal Yetkin|Serdar Hüseyin Yıldırım|Ahmet Reyiz Yılmaz|Baha Cemal Zağra|Khalnazar Agakhanov|Kasymguly Babaýew|Suhan Babaýew|Saparmyrat Batyrow
# Getting page info data for: Ashyrguly Begliyev|Annaguly Deryayev|Mammetmyrat Geldinyyazov|Dangatar Köpekow|Kurban Permanov|Akmyrat Rejepow|Ata Serdarow|Nazar Soýunow|Solofa Uota|Ssendi Mosh Afrikan|Christine Akello|Joan Acom Alobo|Christine Apolot|Kenny Auma|Charles Ayume|Balyeku Moses Grace|Christine Bukenya Ssendawula|Ekwau Ibi Florence|Karubanga Jacob|Jane Awich|Jane Kabajungu Bainomugisha|John Kabaireho|Joseph Kabuleta|Apollo Kaggwa|Michael Kawalya Kagwa|Robert Mugabe Kakyebezi|Joselyn Kamateneti|Amos Mubunga Kambere|Paulo Kavuma|Patrick Kayemba|Kabuye Frank Kibirige|Julia Kibubura|Daniel Kidega|Yabezi Kiiza|Beatrice Kiraso|Kiwanuka Sulaiman|Ruth Molly Lematia|Annie Logiel|Ajok Lucy|Jack Odur Lutanywa|James Mamawi|Margaret Rwebyambu|Margret Okunga Makoha|Jack Maumbe Mukhwana|Willy Mayambala|Kibirige Mayanja|Tamale Mirundi|Milly Mugeni|Isaac Mulindwa|Besueri Kiwanuka Lusse Mulondo
# Getting page info data for: Victoria Mwaka|Fred Mwesigye|Mary Annet Nakato|Faridah Nambi|Ndyomugyenyi Roland Bish|Linos Ngompek|Asinansi Nyakato|Geoffrey Onegi Obel|Onegi Obel|James Obita|Apollo Ofwono|Amos Okot|Moses Okot Jr|Okullo Aabuka Jallon Anthony|Bosmic Otim|Patrick Nsamba Oshabe|Ricky Richard Anywar|Flavia Rwabuhoro Kabahenda|Eric Sakwa|Sitenda Sebalu|Mayanja Kyompitira Sebalu|Simeo Muwanga Nsubuga|Wilson Tumwine|Sarah Nambozo Wekomba|Yakiv Apter|Volodymyr Artyukh|Alexander Barybin|Olha Bench|Serhiy Berezenko|Andriy Beshta|Ivan Bisyuk|Volodymyr Boyko|Ihor Dolhov|Anatoliy Fedorchuk|Ivan Gel|Olena Halushka|Izet Hdanov|Artur Herasymov|Valeriy Holovko|Volodymyr Hryshchenko|Stepan Ivakhiv|Borys Kachura|Dmytro Kashchuk|Serhii Khlan|Borys Klimchuk (politician)|Klitschko brothers|Mykola Kolisnyk|Mykhailo Korolenko|Ivan Korshynskyi|Roman Kostenko
# Getting page info data for: Heorhiy Kryuchkov|Mykola Kulinich|Vitalii Kurylo|Anatolii Kutsevol|Ihor Kyzym|Hennadiy Lahuta|Yurii Lavreniuk|Andriy Levus|Ivan Lypa|Roman Mashovets|Denys Maslov|Volodymyr Matvienko|Pavlo Matvienko|Oleh Meidych|Mykola Popov|Denys Myrgorodskyi|Sergey Nazarov|Andriy Odarchenko|Hryhoriy Omelchenko|Volodymyr Petrov|Mykola Petruk|Vasyl Poraiko|Yelena Protsenko|Mykhailo Reznik|Oleksandr Ryzhenkov|Petro Gadz|Ruslan Magomedov (economist)|Oleksandr Ruzhytskyi|Mykola Riabovil|Vladimir Saldo|Olena Semeniaka|Volodymyr Serhiychuk|Oleh Shamshur|Vyacheslav Shapovalov|Serhii Shapran|Iryna Stavchuk|Volodymyr Stelmakh|Viacheslav Suprunenko|Taras Tarasenko|Volodymyr Tsvil|Volodymyr Tyahlo|Serhiy Tymchenko|Kyrylo Tymoshenko|Evgeniy Udod|Dmytro Vorona|Mykola Yankovsky|Kostiantyn Yastrub|Yuriy Vozniuk|Andriy Yusov|Anatoliy Zasukha
# Getting page info data for: Vitaly Zholobov|Luis Almagro|Sebastián Bauzá|Mónica Bottero|Jorge Bruni|Guillermo Chifflet|Laura Cortinas|Guillermo Domenech|Lorenzo Antonio Fernández|Pedro Figari|Liliam Kechichián|Dámaso Antonio Larrañaga|Juan Francisco Larrobla|Eduardo Lorier|Hector Luisi|Guido Manini Ríos|Isidoro de María|Luis Melián Lafinur|Antonio Mercader|Pablo Mieres|José Benito Monterroso|Tristán Narvaja|Gonzalo Nin Novoa|Edgardo Novick|María Inés Obaldía|Yamandú Orsi|José Brito del Pino|Enrique Pintado|Carlos Pita (politician)|Carlos Quijano|Laura Raffo|José Rondeau|Florencio Sánchez|José Pedro Varela|Pedro Vaz (diplomat)|Mateo Vidal|Jorge Zabalza|Ikhtiyor Abdullayev|Adham Ahmedbaev|Jakhongir Artikkhodjayev|Valery Ataev|Abdusalom Azizov|Uktam Barnoev|Sa'dulla Begaliyev|Rustam Inoyatov|Rashid Kadyrov|Karim Kamalov|Tatyana Karimova|Erkin Khalilov|Sherzodkhon Kudratkhuja
# Getting page info data for: Bakhodir Kurbanov (general)|Jahangir Mamatov|Rimajon Xudoyberganova|Boʻritosh Mustafoyev|Bahrom Norqobilov|Narzullo Oblomurodov|Ravshanbek Qurbonov|Baxtiyor Rahimov|Bekjon Rakhmonov|Bakhodir Khan Turkistan|Qobul Tursunov|Vincent Lunabek|President of Vanuatu|Jimmy Stevens (politician)|Dinh Van Than|Fernando Adames Torres|Ivonne Attas|Fidel Barbarito|Pedro Bastidas|Alejandra Benítez|José Brito (politician)|Buenaventura Macabeo Maldonado Vivas|Rubén González Cárdenas|José Curiel|Felix Díaz Ortega|Vicente José Gregorio Díaz Silva|Alí Domínguez|Franklyn Duarte|Alberto Franceschi|Arnoldo Gabaldón|Vladimir Gessen (Venezuelan politician)|Jorge Giordani|César González Martínez|Luis Graterol Caraballo|Liborio Guarulla|José Bernabé Gutiérrez|María Cristina Iglesias|Reinaldo Iturriza|Andrés Izarra|Reinaldo Leandro Mora|Carlos Augusto León|Ramón Lobo (economist)|Jorge Elieser Márquez|Américo Martín|Nelson Martínez (politician)|Francisco de Miranda|Reinaldo Muñoz Pedroza|Dia Nader de El-Andari|Moisés Naím|Freddy Ñáñez
# Getting page info data for: Pablo Acosta Ortiz|Renny Ottolina|Alejandro Peña Esclusa|Miguel Peña (politician)|Lewis Pérez|Arkiely Perfecto|Eduardo Piñate|Humberto Prado|Omar Prieto|Benjamín Rausseo|Manuel Felipe Rugeles|Carlos Santana Tovar|Milena Sardi de Selle|Carlos Eduardo Stolk|Bolivia Suárez|Gustavo Tarre|José Herrera Uslar|Addy Valero|José Antonio Velutini|Henry Ventura|Nervis Villalobos|Bùi Tiến Dũng (politician)|Chu Văn An|Nguyễn Quốc Định|Đinh Xuân Quảng|Kiem Do|Đỗ Quang Giai|Hồ Đắc Điềm|Hồ Văn Nhựt|Hoàng Cao Khải|Hoang Van Chi|Huỳnh Văn Cao|Kiều Mộng Thu|Lê Minh Hương|Lê Quốc Minh|Lê Văn Thành|Lương Thế Huy|Nguyễn Hồng Diên|Nguyễn Đức Chung|Nguyễn Dương Đôn|Nguyễn Duy Quý|Nguyễn Hợp Đoàn|Nguyễn Phan Long|Nguyễn Quốc Cường|Nguyễn Thị Hồng (economist)|Nguyễn Thị Thập|Nguyễn Văn Huyền|Nguyễn Văn Lực|Nguyễn Văn Trân|Nguyễn Văn Xuân
# Getting page info data for: Phan Anh|Tạ Quang Bửu|Tran Minh Tiet|Trần Quốc Vượng (politician)|Trần Văn Hữu|Trương Đình Dzu|Võ Văn Thưởng|Abdullah Noman|Hashid Abdullah al-Ahmar|Himyar Abdullah al-Ahmar|Sam Yahya Al-Ahmar|Ameen Ali al-Akimi|Talal Aklan|Abdullatif Al-Sayed|Muhammad Musa al-Amri|Mohamed al-Atifi|Yasser Al-Awadi|Sagheer Hamoud Aziz|Sultan al-Barakani|Faraj Salmin Al-Bahsani|Ali Al Bukhaiti|Bruce Conde|Abdul Wahab Al-Dailami|Ali Ahmad Nasser al-Dhahab|Badreddin al-Houthi|Ibrahim Bin Ali Al Wazeer|Mohammed Lutf al-Iryani|Abd Al-Rahman Ali Al-Jifri|Hussein Khairan|Mohammed Ali Al-Maqdashi|Hooria Mashhour|Muhammad bin Yahya bin Muhammad|Abdul Qader Qahtan|Abdulwahab al-Rawhani|Mohammed al-Sabry|Yahya Mohamed Abdullah Saleh|Ali Taysir|Yahya Muhammad Hamid ed-Din|Aidarus al-Zoubaidi|Francis Kapyanga|Lily Monze|Olipa Phiri|Gift Banda|Flora Buka|Bulelani Lobengula|Joseph Makamba Busha|Darlington Dzikamai Chigumbu|James Chikerema|Paul Chimedza|Chenhamo Chimutengwende
# Getting page info data for: Ruth Chinamano|George Chiweshe|Phillip Chiyangwa|Guy Clutton-Brock|Margaret Dongo|Jabulani Dube|Fletcher Dulini Ncube|Ken Flower|Aguy Georgias|Sithembile Gumbo|Josiah Zion Gumede|Ellen Gwaradzimba|Andre Sothern Holland|Byron Hove|Tonderai Kasu|Wilson Khumbula|Lovemore Madhuku|Sarah Mahoka|Alfred Makwarimba|Washington Malianga|Elliot Manyika|Linda Masarira|Jevan Maseko|Anxious Masuka|Lovemore Matombo|Bright Matonga|Isaac Matongo|Obedingwa Mguni|Promise Mkwananzi|Max Mnkandla|Bekithemba Mpofu|Earnest Mudzengi|Mugabe family|Kisinoti Mukwazhe|Edwin Mushoriwa|Munacho Mutezo|Abel Muzorewa|Prag Lalloo Naran|Owen Ncube|Nhlanhlayamangwe Felix Ndiweni|Gundwane Ndiweni|Khayisa Ndiweni|Jane Ngwenya|Maurice Nyagumbo|George Nyandoro|Sekai Nzenza|Engelbert Rugeje|Tinos Rusere|Scot Sakupwanya|Daniel Shumba
# Getting page info data for: Maxwell Zeb Shumba|Nkululeko Mkastos Sibanda|Leopold Takawira|Gift Tandare|Rekayi Tangwena|Temba Mliswa|Josiah Tongogara|Langton Towungana|Sengezo Tshabangu|Herbert Ushewokunze|Denis Walker

# %% [markdown]
# ### Prepping Data for ORES request
# Desired output:
# `{'title1':lastrevid,  'title2':lastrevid, ...}`

# %%
filtered_politician_page_info = filter_pageinfo(all_page_data)

print(filtered_politician_page_info)
# Out:
# {'Abdul Baqi Turkistani': 1231655023, 'Abdul Ghani Ghani': 1227026187, 'Abdul Rahim Ayoubi': 1226326055, 'Ahmad Wali Massoud': 1221720658, 'Aimal Faizi': 1185105938, 'Amir Muhammad Akhundzada': 1247931713, 'Aziza Ahmadyar': 1195651393, 'Azizullah Lodin': 1247762293, 'Baran Khan Kudezai': 1176481824, 'Bashir Ahmad Bezan': 1248505877, 'Cheragh Ali Cheragh': 1193992206, 'Ezatullah (Nangarhar)': 1158302291, 'Fazel Ahmed Manawi': 1234514379, 'Gajinder Singh Safri': 1212323536, 'Ghulam Ghaus': 1158659195, 'Ghulam Muhammad Ghobar': 1240993642, 'Hafizullah Shabaz Khail': 1238402857, 'Haroon al-Afghani': 1230459615, 'Hashmat Ghani Ahmadzai': 1207743719, 'Ismael Balkhi': 1244521219, 'Jan Baz': 1227635806, 'Khadija Zahra Ahmadi': 1234741562, 'Mahboba Hoqomal': 1243745950, 'Majah Ha Adrif': 1233202991, 'Masoud Khalili': 1246566971, 'Mirza Muhammad Ismail': 1235165845, 'Moeen Marastial': 1246567093, 'Mohammad Daud Miraki': 1227103354, 'Mohammad Ghous Bashiri': 1237694188, 'Mohammad Gul (Helmand Council)': 1136611354, 'Mohammad Khan (athlete)': 1247727443, 'Mohammad Sarwar Ahmedzai': 1176429234, 'Mohammad Siddiq Chakari': 1134129082, 'Muhammad Hashim Esmatullahi': 949986748, 'Muqadasa Ahmadzai': 1235521766, 'Musa Hotak': 1246566804, 'Nasir Ahmad Durrani': 988838315, 'Nasrullah Baryalai Arsalai': 1225385278, 'Qutbuddin Hilal': 1246566795, 'Rafiullah Bidar': 1197443408, 'Rangina Hamidi': 1234743111, 'Razaq Mamoon': 1227180106, 'Said Tayeb Jawad': 1248976824, 'Samoud Khan': 1195409073, 'Sayed Jalal': 1137130537, 'Sayed Jalal Karim': 1136614743, 'Sayed Yousuf Halim': 1234514565, 'Sayed Zafar Hashemi': 1179137138, 'Sharif Ghalib': 1245967190, 'Tayyab Agha': 1225661708, 'Abdul Ghafor Zori': 1136614520, 'Abdul Karim Misaq': 1235405154, 'Abdul Majid Samim': 1225425205, 'Abdul Salam Zaeef': 1243758857, 'Abdul Sattar Mirzakwal': 1145249317, 'Abdul Zahir (Konar Education Minister)': 1126667481, 'Ahmadullah Wasiq': 1171042170, 'Ali Mohammad (politician)': 1136630194, 'Ali Pasha of Gusinje': 1244421894, 'Azis Tahir Ajdonati': 1192928746, 'Baktash Siawash': 1236603169, 'Bardhok Biba': 1250227174, 'Bislim Bajgora': 1217284690, 'Daoud Naji': 1247131367, 'Davood Moradian': 1239319380, 'Fazal Hadi Shinwari': 1242412237, 'Gholam Rabani Nasher': 1136534788, 'Ghulam Faroq Nijrabi': 1136614778, 'Ghulam Hassan Safi': 1176507815, 'Ghulam Mohammad Rigi': 1129192917, 'Gul Ahmmad Yama': 1136614561, 'Hanifa Safi': 1123824802, 'Hasan Ali Sultani': 1136614726, 'Hysni Curri': 1198914812, 'Ibrahim Dalliu': 1248264998, 'Kastriot Berissa': 1244463139, 'Kostandin Boshnjaku': 1250227994, 'Mohammad Hashem Taufiqui': 1233490009, 'Mohammed Qalamuddin': 1178097642, 'Mohammed Tahir Omar': 1185088733, 'Mohammed Zaman': 1229734414, 'Mohammed Zia Salehi': 1225457074, 'Nasruddin Mohseni': 1136630129, 'Neritan Ceka': 1184807608, 'Niazi Demi': 1209346411, 'Pacha Gul Wafadar': 1227179979, 'Qari Ziauddin': 1245217124, 'Refo Çapari': 1222381064, 'Saber Sangar': 1227951669, 'Safet Butka': 1189442848, 'Sardar Mohammad Nadir Naeem': 1204109653, 'Sayed Nasim Mihanparast': 1172646418, 'Spartak Braho': 1224650124, 'Suhail Shaheen': 1198363158, 'Uran Butka': 1196422551, 'Wahidullah Waissi': 1232389768, 'Ylli Asllani': 1221605713, 'Zabih-U-llah Ghazi Noristani': 1136614682, 'Zalmai Mujadidi': 1223903677, 'Ziauddin (Afghan militia leader)': 1150044800, 'Abas Ermenji': 1240801210, 'Abdurrahman Dibra': 1244008227, 'Adrian Neritani': 1196135017, 'Afrim Tole': 1241836925, 'Ahmed Dino': 1209165678, 'Alfred Karamuço': 1098236555, 'Ali Këlcyra': 1227369252, 'Aqif Pasha Elbasani': 1243882903, 'Artur Kuko': 1112281132, 'Athanas Shundi': 1220369492, 'Avni Rustemi': 1229276965, 'Aćif Hadžiahmetović': 1229938943, 'Bajram Kelmendi': 1237006808, 'Bedri Pejani': 1220757655, 'Behxhet Nepravishta': 1180949734, 'Bujar Dida': 1222151681, 'Chatin Sarachi': 1141930406, 'Eduard Shalsi': 1173107489, 'Elez Koçi': 1174010569, 'Ferhat Bey Draga': 1236738861, 'Gjon Markagjoni': 1227760361, 'High Council of Regency': 12454503 ...

# %% [markdown]
# This is a check to see if after the API call, we are missing any politicians.

# %%
missing_politicians = []

# Check to see if there are any politicians missing between politician_list and ARTICLE_REVISIONS
for politician in politician_list:
    if politician not in filtered_politician_page_info:
        missing_politicians.append(politician)

# Save the missing politicians to missing_politicians.json
with open('missing_politicians.json', 'w') as f:
    json.dump(missing_politicians, f, indent=4)

total_politicians = len(politician_list)
missing_count = len(missing_politicians)

print(f"\nTotal Politicians in List from Wiki Crawl: {total_politicians}")
print(f"Politicians Missing from filtered_politician_page_info: {missing_count}")

if missing_politicians:
    print("\nThe following politicians are missing from API Call:")
    for missing in missing_politicians:
        print(missing)
else:
    print("\nAll politicians in the list are found in filtered_politician_page_info.")
# Out:
# Total Politicians in List from Wiki Crawl: 7111
# Politicians Missing from filtered_politician_page_info: 8
# Politicians Found in filtered_politician_page_info: 7103
#
# The following politicians are missing from API Call:
# Barbara Eibinger-Miedl
# Mehrali Gasimov
# Kyaw Myint
# André Ngongang Ouandji
# Tomás Pimentel
# Richard Sumah
# Segun ''Aeroland'' Adewale
# Bashir Bililiqo

# %% [markdown]
# # Part C: Requesting ORES scores through LiftWing ML Service API
# Wikimedia Foundation (WMF) is reworking access to their APIs. It is likely in the coming years that all API access will require some kind of authentication, either through a simple key/token or through some version of OAuth. For now this is still a work in progress. You can follow the progress from their [API portal](https://api.wikimedia.org/wiki/Main_Page). Another on-going change is better control over API services in situations where those services require additional computational resources, beyond simply serving the text of a web page (i.e., the text of an article). Services like ORES that require running an ML model over the text of an article page is an example of a compute intensive API service.
#
# Wikimedia is implementing a new Machine Learning (ML) service infrastructure that they call [LiftWing](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing). Given that ORES already has several ML models that have been well used, ORES is the first set of APIs that are being moved to LiftWing.
#
# This example illustrates how to generate article quality estimates for article revisions using the LiftWing version of [ORES](https://www.mediawiki.org/wiki/ORES). The [ORES API documentation](https://ores.wikimedia.org) can be accessed from the main ORES page. The [ORES LiftWing documentation](https://wikitech.wikimedia.org/wiki/Machine_Learning/LiftWing/Usage) is very thin ... even thinner than the standard ORES documentation. Further, it is clear that some parameters have been renamed (e.g., "revid" in the old ORES API is now "rev_id" in the LiftWing ORES API).
#
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 15, 2023.
#
# This current code block includes modifications by Sarah Nguyen, specifically:
# - Adding the variables `user`, `personal_token`, and `personal_email` to avoid using part of the sample code which involved encoding your private information and have removed it manually
# - I removed the apikeys.zip file to avoid using the encoding functions

# %% [markdown]
# # Get your access token
#
# You will need a Wikimedia user account to get access to Lift Wing (the ML API service). You can either [create an account or login](https://api.wikimedia.org/w/index.php?title=Special:UserLogin). If you have a Wikipedia user account - you might already have an Wikimedia account. If you are not sure try your Wikipedia username and password to check it. If you do not have a Wikimedia account you will need to create an account that you can use to get an access token.
#
# There is [a 'guide' that describes how to get authentication tokens](https://api.wikimedia.org/wiki/Authentication) - but not everything works the way it is described in that documentation. You should review that documentation and then read the rest of this comment.
#
# The documentation talks about using a "dashboard" for managing authentication tokens. That's a rather generous description for what looks like a simple list of token things. You might have a hard time finding this "dashboard". First, on the left hand side of the page, you'll see a column of links. The bottom section is a set of links titled "Tools". In that section is a link that says [Special pages](https://api.wikimedia.org/wiki/Special:SpecialPages) which will take you to a list of ... well, special pages. At the very bottom of the "Special pages" page is a section titled "Other special pages" (scroll all the way to the bottom). The first link in that section is called [API keys](https://api.wikimedia.org/wiki/Special:AppManagement). When you get to the "API keys" page you can create a new key.
#
# The authentication guide suggests that you should create a server-side app key. This does not seem to work correctly - as yet. It failed on multiple attempts when I attempted to create a server-side app key. BUT, there is an option to create a [Personal API token](https://api.wikimedia.org/wiki/Authentication) that should work for this course and the type of ORES page scoring that you will need to perform.
#
# Note, when you create a Personal API token you are granted the three items - a Client ID, a Client secret, and a Access token - you shold save all three of these. When you dismiss the box they are gone. If you lose any one of the tokens you can destroy or deactivate the Personal API token from the dashboard and then create a new one.
#
# The value you need to work the code below is the Access token - a very long string.

# %%
user = "yourusername"
personal_token = "yourverylongpersonaltoken"
personal_email = "yourpersonalemail"

# %%
#########
#
#    CONSTANTS
#

#    The current LiftWing ORES API endpoint and prediction model
#

API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

#
#    The throttling rate is a function of the Access token that you are granted when you request the token. The constants
#    come from dissecting the token and getting the rate limits from the granted token. An example of that is below.
#
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0*60.0)/5000.0)-API_LATENCY_ASSUMED  # The key authorizes 5000 requests per hour

#    When making automated requests we should include something that is unique to the person making the request
#    This should include an email - your UW email would be good to put in there
#
#    Because all LiftWing API requests require some form of authentication, you need to provide your access token
#    as part of the header too
#
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "<{email_address}>, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}
#
#    This is a template for the parameters that we need to supply in the headers of an API request
#
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address' : personal_email,         # your email address should go here
    'access_token'  : personal_token # the access token you create will need to go here
}

#
#    A dictionary of English Wikipedia article titles (keys) and sample revision IDs that can be used for this ORES scoring example
#
ARTICLE_REVISIONS = filtered_politician_page_info

#
#    This is a template of the data required as a payload when making a scoring request of the ORES model
#
ORES_REQUEST_DATA_TEMPLATE = {
    "lang":        "en",     # required that its english - we're scoring English Wikipedia revisions
    "rev_id":      "",       # this request requires a revision id
    "features":    True
}

#
#    These are used later - defined here so they, at least, have empty values
#
USERNAME = user
ACCESS_TOKEN = personal_token
#

# %% [markdown]
# ## Define a function to make the ORES API request
#
# The API request will be made using a function to encapsulate call and make access reusable in other notebooks. The procedure is parameterized, relying on the constants above for some important default parameters. The primary assumption is that this function will be used to request data for a set of article revisions. The main parameter is 'article_revid'. One should be able to simply pass in a new article revision id on each call and get back a python dictionary as the result. A valid result will be a dictionary that contains the probabilities that the specific revision is one of six different article quality levels. Generally, quality level with the highest probability score is considered the quality level for the article. This can be tricky when you have two (or more) highly probable quality levels.
#
# This is a continuation of Dr. David W. McDonald's example code for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.0 - August 15, 2023.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, email_address=None, access_token=None,
                                   endpoint_url = API_ORES_LIFTWING_ENDPOINT,
                                   model_name = API_ORES_EN_QUALITY_MODEL,
                                   request_data = ORES_REQUEST_DATA_TEMPLATE,
                                   header_format = REQUEST_HEADER_TEMPLATE,
                                   header_params = REQUEST_HEADER_PARAMS_TEMPLATE):

    #    Make sure we have an article revision id, email and token
    #    This approach prioritizes the parameters passed in when making the call
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token

    #   Making a request requires a revision id - an email address - and the access token
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision id (rev_id) to score articles")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value")

    # Create the request URL with the specified model parameter - default is a article quality score request
    request_url = endpoint_url.format(model_name=model_name)

    # Create a compliant request header from the template and the supplied parameters
    headers = dict()
    for key in header_format.keys():
        headers[str(key)] = header_format[key].format(**header_params)

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free data
        # source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        #response = requests.get(request_url, headers=headers)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# ### Make an ORES request using the page title and current revision id
#
# - `score_all_articles` is a function to perform ORES scoring for all articles.
#
# The ORES scores are logged and saved in file `ores_scores.json`. Articles which we could not get a score for were logged in `failed_articles.json`

# %%
def score_all_articles(article_revisions, email_address, access_token):
    """
    Retrieve ORES scores for a collection of articles based on their revision IDs.

    This function iterates over a dictionary of article titles and their corresponding revision IDs,
    making ORES API calls to retrieve scoring information for each article. It stores the scores
    in a dictionary and tracks articles that fail to get a score.

    Args:
        article_revisions (dict):
            A dictionary where the keys are article titles and the values are revision IDs.
        email_address (str):
            The user's email address required for authenticating the ORES API requests.
        access_token (str):
            The access token for authenticating ORES API requests.

    Returns:
        tuple:
            - all_scores (dict): A dictionary where keys are article titles and values are the retrieved ORES scores.
            - failed_articles (list): A list of article titles for which ORES scoring failed.

    Raises:
        APIRequestError:
            If an API request fails or raises an exception during the scoring process.
    """
    all_scores = {}  # We are storing the scores for each article in a dict
    failed_articles = []  # If we cannot get a score, we will store here

    # for all articles and revids, we want to get the ores score by passing in the revid, email address, and access token
    for article_title, revision_id in article_revisions.items():
        print(f"Getting LiftWing ORES scores for '{article_title}' with revid: {revision_id}")
        
        try:
            # Make the ORES API call
            score = request_ores_score_per_article(
                article_revid=revision_id,
                email_address=email_address,
                access_token=access_token
            )
            
            # Check if the score is valid, else mark as failed
            if score is None:
                print(f"Failed to retrieve score for '{article_title}'")
                failed_articles.append(article_title)
            else:
                all_scores[article_title] = score
                print(json.dumps(score, indent=4))
                
        except Exception as e:
            print(f"Error retrieving score for '{article_title}': {e}")
            failed_articles.append(article_title)
        
    return all_scores, failed_articles

# %%
# Does ORES scoring for all articles and collects ones that didn't go through
all_article_scores, failed_articles = score_all_articles(
    article_revisions=ARTICLE_REVISIONS,
    email_address=personal_email,
    access_token=ACCESS_TOKEN
)

# %% [markdown]
# ### Please note: In my notebook, there is a cell that has an error here that it cannot find a variable previously used. This is not actually an error, it cannot find it because I ran it in a tmux session and did not want to run it again here in my notebook as it took 3 hours to run. You can find the output file `ores_scores.json` in my repository.

# %%
# saves ORES scores here, ran score_all_articles in a tmux session originally and didn't want to rerun as it took a long time
# so there is a NameError here as I did not run the cell above again in the notebook
with open('ores_scores.json', 'w') as f:
    json.dump(all_article_scores, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 3
#       1 # Save the results to a JSON file
#       2 with open('ores_scores.json', 'w') as f:
# ----> 3     json.dump(all_article_scores, f, indent=4)
#
# NameError: name 'all_article_scores' is not defined

# %%
# stores articles that did not get score 
with open('failed_articles.json', 'w') as f:
    json.dump(failed_articles, f, indent=4)

# %% [markdown]
# As my failed articles were empty, I wanted to do an extra validation comparing politicial in original input `ARTICLE_REVISIONS` to politician in final ORES output `ores_score.json` to ensure I got scores for each article. I also did this separately as it took 3 hours for it to run in the loop, so checking again that way would've taken too long.

# %%
with open('ores_scores.json', 'r') as f:
    ores_scores = json.load(f)

failed_articles = []

ARTICLE_REVISIONS = filtered_politician_page_info 

# Comparing the keys in ARTICLE_REVISIONS to those in ores_scores
for article_title in ARTICLE_REVISIONS:
    if article_title not in ores_scores:
        failed_articles.append(article_title)

# Now saving the failed articles to failed_articles.json
with open('failed_articles.json', 'w') as f:
    json.dump(failed_articles, f, indent=4)

# Calculate the error rate
total_articles = len(ARTICLE_REVISIONS)
failed_count = len(failed_articles)
error_rate = (failed_count / total_articles) * 100
print(f"\nTotal Articles: {total_articles}")
print(f"Failed Articles: {failed_count}")
print(f"Error Rate: {error_rate:.2f}%")

# Per the assignments request, checking our error rate
if error_rate > 1:
    print("Error rate exceeds 1%. Please review the code and investigate the issue.")
# Out:
# Total Articles: 7103
# Failed Articles: 0
# Error Rate: 0.00%

# %% [markdown]
# # Step 3: Combining the Datasets
# After retrieving and including the ORES data for each article, you'll need to merge the wikipedia data and population data together. Both have fields containing country names for just that purpose. After merging the data, you'll invariably run into entries which cannot be merged. Either the population dataset does not have an entry for the equivalent Wikipedia country, or vice-versa.
#
# ## Output Files:
#
# Identify all countries for which there are no matches and output a list of those countries, with each country on a separate line called:
# `wp_countries-no_match.txt`
# Consolidate the remaining data into a single CSV file called:
# `wp_politicians_by_country.csv`
#
#
# GPT-4 was used to help generate the code block and comments below. I prompted GPT with my own code for merging, renaming, reordering, and checking for missing countries in the merged dataset with the `population_by_country_AUG.2024`, and asked it to help extract the revision ID and article quality score from `ores_scores.json` and create a new intermediary dataframe called `article_quality_df`.
#
# The first step was to begin by combining `politicians_by_country_AUG.2024.csv` and `ores_scores.json` to extract the article_quality scores for each politician. I then took that merged dataframe `article_quality_df` to help generate the final output files.

# %%
with open('ores_scores.json', 'r') as f:
    ores_scores = json.load(f)

# Extract article quality predictions and revision IDs from the ORES scores
article_quality_scores = {}
revision_ids = {}

for politician, data in ores_scores.items():
    try:
        # Get the most recent revision's articlequality prediction
        revision_id = list(data['enwiki']['scores'].keys())[0]  # Extract lastrevid
        prediction = data['enwiki']['scores'][revision_id]['articlequality']['score']['prediction']
        
        # Store the article quality and revision_id
        article_quality_scores[politician] = prediction
        revision_ids[politician] = revision_id
    except KeyError:
        article_quality_scores[politician] = 'Unknown'
        revision_ids[politician] = None

# Create a DataFrame from the article quality scores and revision IDs
article_quality_df = pd.DataFrame({
    'name': list(article_quality_scores.keys()),
    'article_quality': list(article_quality_scores.values()),
    'revision_id': list(revision_ids.values())
})

# Merge the politicians_data with the article_quality_df on the 'name' column
wp_politicians_by_country = pd.merge(politicians_data, article_quality_df, how='left', on='name')

# Step: Standardize country names to match between datasets
wp_politicians_by_country['country'] = wp_politicians_by_country['country'].replace({
    'Guinea-Bissau': 'GuineaBissau',  # Match 'GuineaBissau' in population data
    'Korea, South': 'Korea (South)',  # Match 'Korea (South)'
    'Korea, North': 'Korea (North)'   # Match 'Korea (North)'
})

# Forward-fill the region for all countries in the population dataset
population_data['is_region'] = population_data['Geography'].str.isupper()
population_data['Region'] = population_data['Geography'].where(population_data['is_region']).ffill()

# Filter out the regions for country-level merging
population_countries = population_data[~population_data['is_region']].copy()

# Merge the politicians data (with ORES scores) and population data
merged_data = pd.merge(wp_politicians_by_country, population_countries, how='outer', left_on='country', right_on='Geography')

# Drop redundant columns and clean up
merged_data = merged_data.drop(columns=['Geography', 'is_region'])

# Reorder and rename columns to match the desired output format
merged_data = merged_data[['country', 'Region', 'Population', 'name', 'revision_id', 'article_quality']]
merged_data.rename(columns={'Region': 'region', 'Population': 'population', 'name': 'article_title'}, inplace=True)

# Save the merged data to a CSV file
merged_data.to_csv('wp_politicians_by_country.csv', index=False)

# Step 1: Extract unique countries from both datasets
# Extract country names from politicians_data
politician_countries = set(wp_politicians_by_country['country'].unique())

# Extract country names from population_data, excluding regions (ALL CAPS entries)
population_countries = set(population_countries['Geography'].unique())

# Extract country names from merged_data
merged_countries = set(merged_data['country'].dropna().unique())

# Step 2: Identify countries in politicians_data but missing in the population_data
missing_in_population_data = politician_countries - population_countries

# Step 3: Identify countries in population_data but missing in the politicians_data
missing_in_politicians_data = population_countries - politician_countries

# Combine both missing sets of countries into one list
all_missing_countries = sorted(list(missing_in_population_data | missing_in_politicians_data))

# Step 4: Save all unmatched countries to a text file
with open('wp_countries-no_match.txt', 'w') as f:
    for country in all_missing_countries:
        f.write(f"{country}\n")

# Print the summary of unmatched countries
print(f"Total number of missing countries: {len(all_missing_countries)}")

# Output the first few rows of the merged data for verification
merged_data.head()
# Out:
# Total number of missing countries: 42
#        country      region  population         article_title revision_id  \
# 0  Afghanistan  SOUTH ASIA        42.4        Majah Ha Adrif  1233202991
# 1  Afghanistan  SOUTH ASIA        42.4     Haroon al-Afghani  1230459615
# 2  Afghanistan  SOUTH ASIA        42.4           Tayyab Agha  1225661708
# 3  Afghanistan  SOUTH ASIA        42.4  Khadija Zahra Ahmadi  1234741562
# 4  Afghanistan  SOUTH ASIA        42.4        Aziza Ahmadyar  1195651393
#
#   article_quality
# 0           Start
# 1               B
# 2           Start
# 3            Stub
# 4           Start

# %% [markdown]
# # Step 4: Analysis
# The analysis will consist of calculating `total-articles-per-capita` (a ratio representing the number of articles per person)  and `high-quality-articles-per-capita` (a ratio representing the number of high quality articles per person) on a country-by-country and regional basis.
#
# To find `total-articles-per-capita`, we first grouped our merged dataset by country and region, counting the total number of Wikipedia articles per country. The dataset provided article information, and by grouping it, we could calculate the total number of articles available for each country and region.
#
# To find `high-quality-articles-per-capita`, we filtered the dataset to include only articles that were predicted by ORES to be in the "FA" (Featured Article) or "GA" (Good Article) classes. These articles are considered "high quality" based on our assignment's criteria. We grouped this filtered dataset by country and region, counting how many high-quality articles each country had.
#
# Next, we merged the article counts (both total and high-quality) with population data, using the country as the common key. Population data was provided in millions, so we converted it to individuals for more precise per capita calculations. The `articles-per-capita` was calculated by dividing the total number of articles by the population of each country. Similarly, the `high-quality-articles-per-capita` was calculated by dividing the number of high-quality articles by the population.
#
# To handle edge cases where the population might be missing or zero, we replaced any NaN or infinity values (resulting from division by zero) with 0 to avoid errors in the calculations.
#
# Finally, we sorted the data by region and country to improve readability and saved the results into a CSV file for further analysis.
#
# ### Please note, I converted the population from millions to individuals for more accurate ratios

# %%
# Based on assignment, filter for high qual articles
high_quality_articles = merged_data[merged_data['article_quality'].isin(['FA', 'GA'])]

# First we will want to group by country and region to count total articles and high-quality articles
article_counts = merged_data.groupby(['country', 'region']).size().reset_index(name='total_articles')
high_quality_counts = high_quality_articles.groupby(['country', 'region']).size().reset_index(name='high_quality_articles')

article_summary = pd.merge(article_counts, high_quality_counts, how='left', on=['country', 'region'])
article_summary = pd.merge(article_summary, population_data, how='left', left_on='country', right_on='Geography')
article_summary = article_summary.drop(columns=['Geography'])

# To avoid bad data, replace NaNs in high_quality_articles and Pop with 0 for countries without high-quality articles and in case of unmatched countries
article_summary['high_quality_articles'] = article_summary['high_quality_articles'].fillna(0)
article_summary['Population'] = article_summary['Population'].fillna(0)

# Then, we will convert the population from millions to individuals for more accurate ratios
article_summary['Population'] = article_summary['Population'] * 1_000_000

# Calculate total and high quality articles per capita
article_summary['articles_per_capita'] = article_summary['total_articles'] / article_summary['Population']
article_summary['high_quality_articles_per_capita'] = article_summary['high_quality_articles'] / article_summary['Population']

# In some cases, the population of the country is so small it appears as zero since the population
# file provides the number in millions. Therefore, we want to handle cases where population is zero to avoid division by zero
article_summary['articles_per_capita'] = article_summary['articles_per_capita'].replace([float('inf'), -float('inf')], 0)
article_summary['high_quality_articles_per_capita'] = article_summary['high_quality_articles_per_capita'].replace([float('inf'), -float('inf')], 0)

article_summary = article_summary.sort_values(by=['region', 'country'])
article_summary.to_csv('article_quality_per_capita.csv', index=False)
article_summary.head()
s
# Out:
#                 country     region  total_articles  high_quality_articles  \
# 4   Antigua and Barbuda  CARIBBEAN              33                    0.0
# 9               Bahamas  CARIBBEAN               9                    0.0
# 12             Barbados  CARIBBEAN              25                    0.0
# 39                 Cuba  CARIBBEAN              50                    6.0
# 43   Dominican Republic  CARIBBEAN              38                    2.0
#
#     Population  is_region     Region  articles_per_capita  \
# 4     100000.0      False  CARIBBEAN             0.000330
# 9     400000.0      False  CARIBBEAN             0.000023
# 12    300000.0      False  CARIBBEAN             0.000083
# 39  11000000.0      False  CARIBBEAN             0.000005
# 43  11300000.0      False  CARIBBEAN             0.000003
#
#     high_quality_articles_per_capita
# 4                       0.000000e+00
# 9                       0.000000e+00
# 12                      0.000000e+00
# 39                      5.454545e-07
# 43                      1.769912e-07

# %%
top_10_coverage = article_summary.sort_values(by='articles_per_capita', ascending=False).head(10)
print("\nTop 10 Countries by Coverage (Articles per Capita, Descending Order):")
display(top_10_coverage[['country', 'total_articles', 'articles_per_capita']])
# Out:
# Top 10 Countries by Coverage (Articles per Capita, Descending Order):
#                             country  total_articles  articles_per_capita
# 4               Antigua and Barbuda              33             0.000330
# 51   Federated States of Micronesia              14             0.000140
# 95                 Marshall Islands              13             0.000130
# 151                           Tonga              10             0.000100
# 12                         Barbados              25             0.000083
# 127                      Seychelles               6             0.000060
# 100                      Montenegro              36             0.000060
# 92                         Maldives              33             0.000055
# 17                           Bhutan              44             0.000055
# 123                           Samoa               8             0.000040

# %%
bottom_10_coverage = article_summary.sort_values(by='articles_per_capita', ascending=True).head(10)

print("\nBottom 10 Countries by Coverage (Articles per Capita, Ascending Order):")
display(bottom_10_coverage[['country', 'total_articles', 'articles_per_capita']])
# Out:
# Bottom 10 Countries by Coverage (Articles per Capita, Ascending Order):
#           country  total_articles  articles_per_capita
# 98         Monaco              10         0.000000e+00
# 156        Tuvalu               1         0.000000e+00
# 31          China              16         1.133707e-08
# 67          India             151         1.056979e-07
# 57          Ghana               4         1.173021e-07
# 124  Saudi Arabia               5         1.355014e-07
# 166        Zambia               3         1.485149e-07
# 110        Norway               1         1.818182e-07
# 71         Israel               2         2.040816e-07
# 45          Egypt              32         3.041825e-07

# %%
top_10_high_quality = article_summary.sort_values(by='high_quality_articles_per_capita', ascending=False).head(10)

print("\nTop 10 Countries by High Quality Coverage (Articles per Capita, Descending Order):")
display(top_10_high_quality[['country', 'high_quality_articles', 'high_quality_articles_per_capita']])
# Out:
# Top 10 Countries by High Quality Coverage (Articles per Capita, Descending Order):
#                    country  high_quality_articles  \
# 100             Montenegro                    3.0
# 88              Luxembourg                    2.0
# 1                  Albania                    7.0
# 78                  Kosovo                    4.0
# 92                Maldives                    1.0
# 87               Lithuania                    4.0
# 38                 Croatia                    5.0
# 63                  Guyana                    1.0
# 113  Palestinian Territory                    6.0
# 131               Slovenia                    2.0
#
#      high_quality_articles_per_capita
# 100                      5.000000e-06
# 88                       2.857143e-06
# 1                        2.592593e-06
# 78                       2.352941e-06
# 92                       1.666667e-06
# 87                       1.379310e-06
# 38                       1.315789e-06
# 63                       1.250000e-06
# 113                      1.090909e-06
# 131                      9.523810e-07

# %%
bottom_10_high_quality = article_summary.sort_values(by='high_quality_articles_per_capita', ascending=True).head(10)

print("\nBottom 10 Countries by High Quality Coverage (Articles per Capita, Ascending Order):")
display(bottom_10_high_quality[['country', 'high_quality_articles', 'high_quality_articles_per_capita']])
# Out:
# Bottom 10 Countries by High Quality Coverage (Articles per Capita, Ascending Order):
#                             country  high_quality_articles  \
# 4               Antigua and Barbuda                    0.0
# 37                    Cote d'Ivoire                    0.0
# 110                          Norway                    0.0
# 55                           Gambia                    0.0
# 49                          Estonia                    0.0
# 62                     GuineaBissau                    0.0
# 85                          Liberia                    0.0
# 47                Equatorial Guinea                    0.0
# 51   Federated States of Micronesia                    0.0
# 34                            Congo                    0.0
#
#      high_quality_articles_per_capita
# 4                                 0.0
# 37                                0.0
# 110                               0.0
# 55                                0.0
# 49                                0.0
# 62                                0.0
# 85                                0.0
# 47                                0.0
# 51                                0.0
# 34                                0.0

# %%
# There are two ways to do this, use the population in the region or sum up all the regions
# and calculate the total articles and high-quality articles for each region. I have chosen the later as I felt calculating per country was 
# more granular. Therefore, you might get different answers if you use the population region provided in the table.

region_summary = article_summary.groupby('region').agg(
    # First we want the total num of articles and high quality articles
    total_articles=('total_articles', 'sum'),  
    high_quality_articles=('high_quality_articles', 'sum'),  
    # Then get the population per region
    total_population=('Population', 'sum') 
).reset_index()

# Now, we calculate articles per capita and high-quality articles per capita for each region
region_summary['articles_per_capita'] = region_summary['total_articles'] / region_summary['total_population']
region_summary['high_quality_articles_per_capita'] = region_summary['high_quality_articles'] / region_summary['total_population']
region_summary = pd.DataFrame(region_summary)

# %%
# Sort the result in descending order by 'articles_per_capita' 
regions_by_coverage = region_summary.sort_values(by='articles_per_capita', ascending=False)

print("\nGeographic Regions by Total Coverage (Articles per Capita, Descending Order):")
display(regions_by_coverage[['region', 'total_articles', 'articles_per_capita']])
# Out:
# Geographic Regions by Total Coverage (Articles per Capita, Descending Order):
#              region  total_articles  articles_per_capita
# 8   NORTHERN EUROPE             191         6.870504e-06
# 9           OCEANIA              72         6.486486e-06
# 0         CARIBBEAN             219         5.983607e-06
# 14  SOUTHERN EUROPE             797         5.260726e-06
# 1   CENTRAL AMERICA             188         3.664717e-06
# 17   WESTERN EUROPE             498         2.746828e-06
# 5    EASTERN EUROPE             709         2.663411e-06
# 16     WESTERN ASIA             610         2.064997e-06
# 13  SOUTHERN AFRICA             123         1.800878e-06
# 4    EASTERN AFRICA             665         1.382824e-06
# 10    SOUTH AMERICA             569         1.338824e-06
# 2      CENTRAL ASIA             106         1.318408e-06
# 15   WESTERN AFRICA             523         1.182455e-06
# 7   NORTHERN AFRICA             302         1.180148e-06
# 6     MIDDLE AFRICA             231         1.144698e-06
# 12   SOUTHEAST ASIA             396         7.020032e-07
# 11       SOUTH ASIA             670         3.301794e-07
# 3         EAST ASIA             230         1.424943e-07

# %%
regions_by_high_quality = region_summary.sort_values(by='high_quality_articles_per_capita', ascending=False)

print("\nGeographic Regions by High Quality Coverage (Articles per Capita, Descending Order):")
display(regions_by_high_quality[['region', 'high_quality_articles', 'total_population','high_quality_articles_per_capita']])
# Out:
# Geographic Regions by High Quality Coverage (Articles per Capita, Descending Order):
#              region  high_quality_articles  total_population  \
# 14  SOUTHERN EUROPE                   53.0      1.515000e+08
# 8   NORTHERN EUROPE                    9.0      2.780000e+07
# 0         CARIBBEAN                    9.0      3.660000e+07
# 1   CENTRAL AMERICA                   10.0      5.130000e+07
# 5    EASTERN EUROPE                   38.0      2.662000e+08
# 13  SOUTHERN AFRICA                    8.0      6.830000e+07
# 17   WESTERN EUROPE                   21.0      1.813000e+08
# 16     WESTERN ASIA                   27.0      2.954000e+08
# 9           OCEANIA                    1.0      1.110000e+07
# 7   NORTHERN AFRICA                   17.0      2.559000e+08
# 2      CENTRAL ASIA                    5.0      8.040000e+07
# 10    SOUTH AMERICA                   19.0      4.250000e+08
# 12   SOUTHEAST ASIA                   25.0      5.641000e+08
# 6     MIDDLE AFRICA                    8.0      2.018000e+08
# 4    EASTERN AFRICA                   17.0      4.809000e+08
# 15   WESTERN AFRICA                   13.0      4.423000e+08
# 11       SOUTH ASIA                   21.0      2.029200e+09
# 3         EAST ASIA                   14.0      1.614100e+09
#
#     high_quality_articles_per_capita
# 14                      3.498350e-07
# 8                       3.237410e-07
# 0                       2.459016e-07
# 1                       1.949318e-07
# 5                       1.427498e-07
# 13                      1.171303e-07
# 17                      1.158301e-07
# 16                      9.140149e-08
# 9                       9.009009e-08
# 7                       6.643220e-08
# 2                       6.218905e-08
# 10                      4.470588e-08
# 12                      4.431838e-08
# 6                       3.964321e-08
# 4                       3.535038e-08
# 15                      2.939182e-08
# 11                      1.034891e-08
# 3                       8.673564e-09
